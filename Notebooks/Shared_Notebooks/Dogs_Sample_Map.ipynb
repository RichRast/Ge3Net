# %%
import os
os.chdir('/home/users/richras/Ge2Net_Repo/')
import os.path as osp
import numpy as np
import pandas as pd
import allel
from src.utils.dataUtil import vcf2npy

# %%
in_path="/scratch/groups/cdbustam/richras/data_in"
out_path="/scratch/groups/cdbustam/richras/data_out"

# %%
metadata_filename = osp.join(in_path,"dogs/Metadata_May2018.xlsx")
metadata = pd.read_excel(open(metadata_filename, 'rb'), engine='openpyxl')
metadata
# Out:
#                 Name_ID   Breed/CommonName   BioProject     BioSample  Sex  \
# 0         AfghanHound01       Afghan Hound  PRJNA208087  SAMN02194722    M
# 1         AfghanHound03       Afghan Hound  PRJNA232497  SAMN02485564    F
# 2         AfghanHound04       Afghan Hound  PRJNA266585  SAMN03168377    M
# 3     AiredaleTerrier01   Airedale Terrier  PRJNA263947  SAMN03580381    M
# 4     AiredaleTerrier02   Airedale Terrier  PRJNA263947  SAMN03580390    F
# ..                  ...                ...          ...           ...  ...
# 718            PER00806  Yorkshire Terrier          NaN           NaN    M
# 719            PER00816  Yorkshire Terrier          NaN           NaN    M
# 720  YorkshireTerrier01  Yorkshire Terrier   PRJEB13468  SAMEA3928145    M
# 721  YorkshireTerrier02  Yorkshire Terrier  PRJNA299099  SAMN04195509    M
# 722                 NaN                NaN          NaN           NaN  NaN
#
#      CoverageAll  CoverageX  CoverageRatio AnalysisName_Phylo  \
# 0       28.37080   15.38870       1.843613         AFGH01_xxx
# 1        7.64333    7.71598       0.990584         AFGH03_xxx
# 2       17.56610    9.92331       1.770186         AFGH04_xxx
# 3       15.57180    9.14245       1.703241         AIRT01_xxx
# 4       34.66110   35.08430       0.987938         AIRT02_xxx
# ..           ...        ...            ...                ...
# 718     13.42880    8.77737       1.529934         PER00806_x
# 719     16.05820    9.56801       1.678322         PER00816_x
# 720     21.18020   11.88950       1.781421         YORK01_xxx
# 721     32.97570   18.44320       1.787960         YORK02_xxx
# 722          NaN        NaN            NaN                NaN
#
#          Phylo_Results Phylo_Bootstrap Phylo_Notes   Other_Information  \
# 0         Afghan Hound             100         NaN  Clone of SCN Donor
# 1         Afghan Hound             100         NaN                 NaN
# 2         Afghan Hound             100         NaN                 NaN
# 3     Airedale Terrier             100         NaN                 NaN
# 4     Airedale Terrier             100         NaN                 NaN
# ..                 ...             ...         ...                 ...
# 718  Yorkshire Terrier             100         NaN                 NaN
# 719  Yorkshire Terrier             100         NaN                 NaN
# 720  Yorkshire Terrier             100         NaN                 NaN
# 721  Yorkshire Terrier             100         NaN                 NaN
# 722                NaN             NaN         NaN                 NaN
#
#      Unnamed: 13
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 718          NaN
# 719          NaN
# 720          NaN
# 721          NaN
# 722          NaN
#
# [723 rows x 14 columns]

# %%
# remove the rows that have null for Breed/CommonName
metadata = metadata[~metadata["Breed/CommonName"].isnull()]

# %%
ref_map = metadata[~metadata["Breed/CommonName"].str.contains("Wolf|Coyote|Dhole|Andean Fox|Jackal")].\
reset_index(drop=True)
ref_map
# Out:
#                 Name_ID   Breed/CommonName   BioProject     BioSample Sex  \
# 0         AfghanHound01       Afghan Hound  PRJNA208087  SAMN02194722   M
# 1         AfghanHound03       Afghan Hound  PRJNA232497  SAMN02485564   F
# 2         AfghanHound04       Afghan Hound  PRJNA266585  SAMN03168377   M
# 3     AiredaleTerrier01   Airedale Terrier  PRJNA263947  SAMN03580381   M
# 4     AiredaleTerrier02   Airedale Terrier  PRJNA263947  SAMN03580390   F
# ..                  ...                ...          ...           ...  ..
# 662            PER00777  Yorkshire Terrier          NaN           NaN   M
# 663            PER00806  Yorkshire Terrier          NaN           NaN   M
# 664            PER00816  Yorkshire Terrier          NaN           NaN   M
# 665  YorkshireTerrier01  Yorkshire Terrier   PRJEB13468  SAMEA3928145   M
# 666  YorkshireTerrier02  Yorkshire Terrier  PRJNA299099  SAMN04195509   M
#
#      CoverageAll  CoverageX  CoverageRatio AnalysisName_Phylo  \
# 0       28.37080   15.38870       1.843613         AFGH01_xxx
# 1        7.64333    7.71598       0.990584         AFGH03_xxx
# 2       17.56610    9.92331       1.770186         AFGH04_xxx
# 3       15.57180    9.14245       1.703241         AIRT01_xxx
# 4       34.66110   35.08430       0.987938         AIRT02_xxx
# ..           ...        ...            ...                ...
# 662     16.50230    9.73722       1.694765         PER00777_x
# 663     13.42880    8.77737       1.529934         PER00806_x
# 664     16.05820    9.56801       1.678322         PER00816_x
# 665     21.18020   11.88950       1.781421         YORK01_xxx
# 666     32.97570   18.44320       1.787960         YORK02_xxx
#
#          Phylo_Results Phylo_Bootstrap Phylo_Notes   Other_Information  \
# 0         Afghan Hound             100         NaN  Clone of SCN Donor
# 1         Afghan Hound             100         NaN                 NaN
# 2         Afghan Hound             100         NaN                 NaN
# 3     Airedale Terrier             100         NaN                 NaN
# 4     Airedale Terrier             100         NaN                 NaN
# ..                 ...             ...         ...                 ...
# 662  Yorkshire Terrier             100         NaN                 NaN
# 663  Yorkshire Terrier             100         NaN                 NaN
# 664  Yorkshire Terrier             100         NaN                 NaN
# 665  Yorkshire Terrier             100         NaN                 NaN
# 666  Yorkshire Terrier             100         NaN                 NaN
#
#      Unnamed: 13
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 662          NaN
# 663          NaN
# 664          NaN
# 665          NaN
# 666          NaN
#
# [667 rows x 14 columns]

# %%
# ref_map = metadata[~metadata["Breed/CommonName"].str.contains(r"\b(?:Wolf|Coyote|Dhole|Andean Fox|Jackal)\b", case=False)].\
# reset_index(drop=True)
# ref_map
# contains(r"\b(?:mix|unknown|vill)\b", case=False)

# %%
# ref_map[~ref_map["Name_ID"].isin(ref_map1["Name_ID"])]

# %%
len(np.unique(ref_map["Breed/CommonName"].values)), np.unique(ref_map["Breed/CommonName"].values)
# Out:
# (171, array(['Afghan Hound', 'Airedale Terrier', 'Alaskan Husky',
#         'Alaskan Malamute', 'Alpine Dachsbracke',
#         'American Hairless Terrier', 'Australian Cattle Dog',
#         'Australian Terrier', 'Basenji',
#         'Bavarian Hound (Bayerischer Gebirgsschweisshund)', 'Beagle',
#         'Bearded Collie', 'Belgian Malinois', 'Belgian Sheepdog',
#         'Belgian Tervuren', 'Berger Blanc Suisse', 'Berger Picard',
#         'Bernese Mountain Dog', 'Black Russian Terrier',
#         'Black and Tan Coonhound', 'Bloodhound', 'Border Collie',
#         'Border Terrier', 'Borzoi', 'Boston Terrier',
#         'Bouvier des Flandres', 'Boxer', 'Brittany', 'Bull Terrier',
#         'Bulldog', 'Bullmastiff', 'Cairn Terrier', 'Cane Corso',
#         'Carolina Dog', 'Caucasian Ovcharka',
#         'Cavalier King Charles Spaniel', 'Chesapeake Bay Retriever',
#         'Chihuahua', 'Chinese Crested', 'Chinese Indigenous Dog',
#         'Chinese Shar-Pei', 'Chinook', 'Chongqing Dog', 'Chow Chow',
#         'Clumber Spaniel', 'Cocker Spaniel (American)',
#         'Curly-Coated Retriever', 'Dachshund', 'Dalmatian', 'Dingo',
#         'Doberman Pinscher', 'East Siberian Laika', 'Elo',
#         'English Cocker Spaniel', 'English Setter',
#         'English Springer Spaniel', 'Entlebucher Sennenhund', 'Eurasier',
#         'Field Spaniel', 'Finnish Lapphund', 'Flat-Coated Retriever',
#         "Fonni's Dog", 'French Bulldog', 'German Hunting Terrier',
#         'German Shepherd Dog', 'German Wirehaired Pointer',
#         'Golden Retriever', 'Gordon Setter', 'Great Dane',
#         'Great Pyrenees', 'Greater Swiss Mountain Dog', 'Greenland Dog',
#         'Greyhound', 'Grossspitz', 'Heideterrier', 'Hovawart',
#         'Irish Setter', 'Irish Terrier', 'Irish Water Spaniel',
#         'Istrian Shorthaired Hound', 'Italian Greyhound',
#         'Jack Russell Terrier', 'Jamthund', 'Jindo', 'Keeshond',
#         'Kerry Blue Terrier', 'Komondor', 'Kromfohrländer', 'Kunming Dog',
#         'Labrador Retriever', 'Lagotto Romagnolo', 'Landseer',
#         'Lapponian Herder', 'Leonberger', 'Lowchen',
#         'MIX: American Cocker Spaniel and Beagle', 'MIX: Dachsund',
#         'MIX: Golden Retriever', 'MIX: Kerry Blue Terrier and Beagle',
#         'MIX: Labrador Retriever', 'MIX: Miniature Schnauzer and Beagle',
#         'MIX: Mixed Breed', 'MIX: Siberian Husky', 'MIX: Tibetan Mastiff',
#         'Mastiff (English)', 'Miniature Bull Terrier ', 'Miniature Poodle',
#         'Miniature Schnauzer', 'New Guinea Singing Dog',
#         'Nigerian Indigenous Dog', 'Norwegian Elkhound',
#         'Norwegian Lundehund', 'Norwich Terrier',
#         'Nova Scotia Duck Tolling Retriever', 'Pekingese',
#         'Pembroke Welsh Corgi', 'Peruvian Inca Orchid',
#         'Petit Basset Griffon Vendeen', 'Pointer (English)', 'Pomeranian',
#         'Poodle unspecified variety', 'Portuguese Podengo',
#         'Portuguese Water Dog', 'Pug', 'Qingchuan Dog',
#         'Rhodesian Ridgeback', 'Rottweiler', 'Saint Bernard', 'Saluki',
#         'Samoyed', 'Scottish Deerhound', 'Scottish Terrier',
#         'Shetland Sheepdog', 'Shiba Inu', 'Shih Tzu', 'Siberian Husky',
#         'Sloughi', 'Soft Coated Wheaten Terrier', 'Spanish Galgo',
#         'Spanish Water Dog', 'Spinone Italiano', 'Standard Poodle',
#         'Standard Schnauzer', 'Swedish Lapphund', 'Tibetan Mastiff',
#         'Tibetan Mastiff - China', 'Tibetan Terrier', 'Tornjak',
#         'Toy Poodle', 'UNKNOWN', 'Vietnamese Indigenous Dog',
#         'Village Dog - Aboriginal Camp Dog', 'Village Dog - Borneo',
#         'Village Dog - China', 'Village Dog - Egypt',
#         'Village Dog - India', 'Village Dog - Lebanon',
#         'Village Dog - Namibia', 'Village Dog - Papua New Guinea',
#         'Village Dog - Portugal', 'Village Dog - Qatar',
#         'Village Dog - Sub-Saharan Africa', 'Village Dog - Taiwan',
#         'Village Dog - Vietnam', 'Vizsla', 'Weimaraner',
#         'West Highland White Terrier', 'Whippet', 'Xiasi Dog',
#         'Xoloitzcuintli', 'Yorkshire Terrier'], dtype=object))

# %%
sample_map = ref_map[["Name_ID", "Breed/CommonName"]]
sample_map
# Out:
#                 Name_ID   Breed/CommonName
# 0         AfghanHound01       Afghan Hound
# 1         AfghanHound03       Afghan Hound
# 2         AfghanHound04       Afghan Hound
# 3     AiredaleTerrier01   Airedale Terrier
# 4     AiredaleTerrier02   Airedale Terrier
# ..                  ...                ...
# 662            PER00777  Yorkshire Terrier
# 663            PER00806  Yorkshire Terrier
# 664            PER00816  Yorkshire Terrier
# 665  YorkshireTerrier01  Yorkshire Terrier
# 666  YorkshireTerrier02  Yorkshire Terrier
#
# [667 rows x 2 columns]

# %%
# form a ref map with the same column for Superpopulation Code (superpop) and Population(granular pop)
ref_sample_map = sample_map.rename(columns={"Name_ID":"Sample", "Breed/CommonName":"Population"})
ref_sample_map["Superpopulation code"] = ref_sample_map["Population"]
ref_sample_map
# Out:
#                  Sample         Population Superpopulation code
# 0         AfghanHound01       Afghan Hound         Afghan Hound
# 1         AfghanHound03       Afghan Hound         Afghan Hound
# 2         AfghanHound04       Afghan Hound         Afghan Hound
# 3     AiredaleTerrier01   Airedale Terrier     Airedale Terrier
# 4     AiredaleTerrier02   Airedale Terrier     Airedale Terrier
# ..                  ...                ...                  ...
# 662            PER00777  Yorkshire Terrier    Yorkshire Terrier
# 663            PER00806  Yorkshire Terrier    Yorkshire Terrier
# 664            PER00816  Yorkshire Terrier    Yorkshire Terrier
# 665  YorkshireTerrier01  Yorkshire Terrier    Yorkshire Terrier
# 666  YorkshireTerrier02  Yorkshire Terrier    Yorkshire Terrier
#
# [667 rows x 3 columns]

# %%
# save ref_sample_map
# ref_sample_map.to_csv(r'/scratch/groups/cdbustam/richras/data_out/dogs/ref_map_a.tsv', index=None, sep='\t')

# %% [markdown]
# # Select the samples to remove based on missing snps

# %%
import os.path as osp
start_chr=1
end_chr=38
pd.options.display.float_format = '{:.2f}'.format
for i in range(start_chr, end_chr+1):
    print(f"chm{i}")
    df_chr = pd.read_csv(''.join([osp.join(out_path,'dogs', 'sm_a/chr'+str(i)),'/chr'+str(i)+'_nMissing.txt']), sep="\t", header=None)
    print(df_chr)
    df_chr_missing = df_chr[2:].copy()
    df_chr_missing.columns=['samples', 'nMissing']
    df_chr_missing['_Missing%'] = df_chr_missing['nMissing']*100/df_chr.iloc[0,1]
    
    df_rm_samples = df_chr_missing[df_chr_missing['_Missing%']>10]
    perc_cols=[col for col in df_rm_outer.columns if '_Missing%' in col] if i>start_chr else '_Missing%'
    print(f"perc_cols:{perc_cols}")
    df_rm_outer = df_rm_outer[['samples', *perc_cols]].merge(df_rm_samples[['samples', '_Missing%']], \
                    how="outer", on="samples") if i>start_chr else df_rm_samples[['samples', '_Missing%']]
    df_rm_outer.rename(columns={'_Missing%':'_Missing%_chr'+str(i)}, inplace=True)
    print(df_rm_outer)
# Out:
# chm1
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  3715358
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:_Missing%
# Empty DataFrame
# Columns: [samples, _Missing%_chr1]
# Index: []
# chm2
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  2637994
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1']
# Empty DataFrame
# Columns: [_Missing%_chr1, samples, _Missing%_chr2]
# Index: []
# chm3
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  2813304
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, samples, _Missing%_chr3]
# Index: []
# chm4
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  2662361
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, samples, _Missing%_chr4]
# Index: []
# chm5
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  2676178
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, samples, _Missing%_chr5]
# Index: []
# chm6
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  2331851
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, samples, _Missing%_chr6]
# Index: []
# chm7
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  2325170
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, samples, _Missing%_chr7]
# Index: []
# chm8
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  2342099
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, samples, _Missing%_chr8]
# Index: []
# chm9
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1748067
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, samples, _Missing%_chr9]
# Index: []
# chm10
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  2102834
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, samples, _Missing%_chr10]
# Index: []
# chm11
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  2196764
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, samples, _Missing%_chr11]
# Index: []
# chm12
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  2174438
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, samples, _Missing%_chr12]
# Index: []
# chm13
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  2000413
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, samples, _Missing%_chr13]
# Index: []
# chm14
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1805969
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, samples, _Missing%_chr14]
# Index: []
# chm15
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1928494
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, samples, _Missing%_chr15]
# Index: []
# chm16
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  2027479
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, samples, _Missing%_chr16]
# Index: []
# chm17
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1985684
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# /share/software/user/open/py-pandas/1.0.3_py36/lib/python3.6/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, samples, _Missing%_chr17]
# Index: []
# chm18
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1814019
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, samples, _Missing%_chr18]
# Index: []
# chm19
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1747369
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, samples, _Missing%_chr19]
# Index: []
# chm20
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1677986
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, samples, _Missing%_chr20]
# Index: []
#
# [0 rows x 21 columns]
# chm21
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1625071
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, samples, _Missing%_chr21]
# Index: []
#
# [0 rows x 22 columns]
# chm22
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1870317
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, samples, _Missing%_chr22]
# Index: []
#
# [0 rows x 23 columns]
# chm23
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1553157
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21', '_Missing%_chr22']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, samples, _Missing%_chr23]
# Index: []
#
# [0 rows x 24 columns]
# chm24
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1494772
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21', '_Missing%_chr22', '_Missing%_chr23']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, samples, _Missing%_chr24]
# Index: []
#
# [0 rows x 25 columns]
# chm25
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1603223
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21', '_Missing%_chr22', '_Missing%_chr23', '_Missing%_chr24']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, _Missing%_chr24, samples, _Missing%_chr25]
# Index: []
#
# [0 rows x 26 columns]
# chm26
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1399852
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21', '_Missing%_chr22', '_Missing%_chr23', '_Missing%_chr24', '_Missing%_chr25']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, _Missing%_chr24, _Missing%_chr25, samples, _Missing%_chr26]
# Index: []
#
# [0 rows x 27 columns]
# chm27
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1409104
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21', '_Missing%_chr22', '_Missing%_chr23', '_Missing%_chr24', '_Missing%_chr25', '_Missing%_chr26']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, _Missing%_chr24, _Missing%_chr25, _Missing%_chr26, samples, _Missing%_chr27]
# Index: []
#
# [0 rows x 28 columns]
# chm28
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1312017
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21', '_Missing%_chr22', '_Missing%_chr23', '_Missing%_chr24', '_Missing%_chr25', '_Missing%_chr26', '_Missing%_chr27']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, _Missing%_chr24, _Missing%_chr25, _Missing%_chr26, _Missing%_chr27, samples, _Missing%_chr28]
# Index: []
#
# [0 rows x 29 columns]
# chm29
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1315790
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21', '_Missing%_chr22', '_Missing%_chr23', '_Missing%_chr24', '_Missing%_chr25', '_Missing%_chr26', '_Missing%_chr27', '_Missing%_chr28']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, _Missing%_chr24, _Missing%_chr25, _Missing%_chr26, _Missing%_chr27, _Missing%_chr28, samples, _Missing%_chr29]
# Index: []
#
# [0 rows x 30 columns]
# chm30
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1181922
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21', '_Missing%_chr22', '_Missing%_chr23', '_Missing%_chr24', '_Missing%_chr25', '_Missing%_chr26', '_Missing%_chr27', '_Missing%_chr28', '_Missing%_chr29']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, _Missing%_chr24, _Missing%_chr25, _Missing%_chr26, _Missing%_chr27, _Missing%_chr28, _Missing%_chr29, samples, _Missing%_chr30]
# Index: []
#
# [0 rows x 31 columns]
# chm31
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1304523
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21', '_Missing%_chr22', '_Missing%_chr23', '_Missing%_chr24', '_Missing%_chr25', '_Missing%_chr26', '_Missing%_chr27', '_Missing%_chr28', '_Missing%_chr29', '_Missing%_chr30']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, _Missing%_chr24, _Missing%_chr25, _Missing%_chr26, _Missing%_chr27, _Missing%_chr28, _Missing%_chr29, _Missing%_chr30, samples, _Missing%_chr31]
# Index: []
#
# [0 rows x 32 columns]
# chm32
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1222521
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21', '_Missing%_chr22', '_Missing%_chr23', '_Missing%_chr24', '_Missing%_chr25', '_Missing%_chr26', '_Missing%_chr27', '_Missing%_chr28', '_Missing%_chr29', '_Missing%_chr30', '_Missing%_chr31']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, _Missing%_chr24, _Missing%_chr25, _Missing%_chr26, _Missing%_chr27, _Missing%_chr28, _Missing%_chr29, _Missing%_chr30, _Missing%_chr31, samples, _Missing%_chr32]
# Index: []
#
# [0 rows x 33 columns]
# chm33
#                       0       1
# 0    number of samples:     667
# 1       number of SNPs:  981145
# 2         AfghanHound01       0
# 3         AfghanHound03       0
# 4         AfghanHound04       0
# ..                  ...     ...
# 664            PER00777       0
# 665            PER00806       0
# 666            PER00816       0
# 667  YorkshireTerrier01       0
# 668  YorkshireTerrier02       0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21', '_Missing%_chr22', '_Missing%_chr23', '_Missing%_chr24', '_Missing%_chr25', '_Missing%_chr26', '_Missing%_chr27', '_Missing%_chr28', '_Missing%_chr29', '_Missing%_chr30', '_Missing%_chr31', '_Missing%_chr32']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, _Missing%_chr24, _Missing%_chr25, _Missing%_chr26, _Missing%_chr27, _Missing%_chr28, _Missing%_chr29, _Missing%_chr30, _Missing%_chr31, _Missing%_chr32, samples, _Missing%_chr33]
# Index: []
#
# [0 rows x 34 columns]
# chm34
#                       0        1
# 0    number of samples:      667
# 1       number of SNPs:  1401538
# 2         AfghanHound01        0
# 3         AfghanHound03        0
# 4         AfghanHound04        0
# ..                  ...      ...
# 664            PER00777        0
# 665            PER00806        0
# 666            PER00816        0
# 667  YorkshireTerrier01        0
# 668  YorkshireTerrier02        0
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21', '_Missing%_chr22', '_Missing%_chr23', '_Missing%_chr24', '_Missing%_chr25', '_Missing%_chr26', '_Missing%_chr27', '_Missing%_chr28', '_Missing%_chr29', '_Missing%_chr30', '_Missing%_chr31', '_Missing%_chr32', '_Missing%_chr33']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, _Missing%_chr24, _Missing%_chr25, _Missing%_chr26, _Missing%_chr27, _Missing%_chr28, _Missing%_chr29, _Missing%_chr30, _Missing%_chr31, _Missing%_chr32, _Missing%_chr33, samples, _Missing%_chr34]
# Index: []
#
# [0 rows x 35 columns]
# chm35
#                       0       1
# 0    number of samples:     667
# 1       number of SNPs:  871160
# 2         AfghanHound01       0
# 3         AfghanHound03       0
# 4         AfghanHound04       0
# ..                  ...     ...
# 664            PER00777       0
# 665            PER00806       0
# 666            PER00816       0
# 667  YorkshireTerrier01       0
# 668  YorkshireTerrier02       0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21', '_Missing%_chr22', '_Missing%_chr23', '_Missing%_chr24', '_Missing%_chr25', '_Missing%_chr26', '_Missing%_chr27', '_Missing%_chr28', '_Missing%_chr29', '_Missing%_chr30', '_Missing%_chr31', '_Missing%_chr32', '_Missing%_chr33', '_Missing%_chr34']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, _Missing%_chr24, _Missing%_chr25, _Missing%_chr26, _Missing%_chr27, _Missing%_chr28, _Missing%_chr29, _Missing%_chr30, _Missing%_chr31, _Missing%_chr32, _Missing%_chr33, _Missing%_chr34, samples, _Missing%_chr35]
# Index: []
#
# [0 rows x 36 columns]
# chm36
#                       0       1
# 0    number of samples:     667
# 1       number of SNPs:  912303
# 2         AfghanHound01       0
# 3         AfghanHound03       0
# 4         AfghanHound04       0
# ..                  ...     ...
# 664            PER00777       0
# 665            PER00806       0
# 666            PER00816       0
# 667  YorkshireTerrier01       0
# 668  YorkshireTerrier02       0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21', '_Missing%_chr22', '_Missing%_chr23', '_Missing%_chr24', '_Missing%_chr25', '_Missing%_chr26', '_Missing%_chr27', '_Missing%_chr28', '_Missing%_chr29', '_Missing%_chr30', '_Missing%_chr31', '_Missing%_chr32', '_Missing%_chr33', '_Missing%_chr34', '_Missing%_chr35']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, _Missing%_chr24, _Missing%_chr25, _Missing%_chr26, _Missing%_chr27, _Missing%_chr28, _Missing%_chr29, _Missing%_chr30, _Missing%_chr31, _Missing%_chr32, _Missing%_chr33, _Missing%_chr34, _Missing%_chr35, samples, _Missing%_chr36]
# Index: []
#
# [0 rows x 37 columns]
# chm37
#                       0       1
# 0    number of samples:     667
# 1       number of SNPs:  977540
# 2         AfghanHound01       0
# 3         AfghanHound03       0
# 4         AfghanHound04       0
# ..                  ...     ...
# 664            PER00777       0
# 665            PER00806       0
# 666            PER00816       0
# 667  YorkshireTerrier01       0
# 668  YorkshireTerrier02       0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21', '_Missing%_chr22', '_Missing%_chr23', '_Missing%_chr24', '_Missing%_chr25', '_Missing%_chr26', '_Missing%_chr27', '_Missing%_chr28', '_Missing%_chr29', '_Missing%_chr30', '_Missing%_chr31', '_Missing%_chr32', '_Missing%_chr33', '_Missing%_chr34', '_Missing%_chr35', '_Missing%_chr36']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, _Missing%_chr24, _Missing%_chr25, _Missing%_chr26, _Missing%_chr27, _Missing%_chr28, _Missing%_chr29, _Missing%_chr30, _Missing%_chr31, _Missing%_chr32, _Missing%_chr33, _Missing%_chr34, _Missing%_chr35, _Missing%_chr36, samples, _Missing%_chr37]
# Index: []
#
# [0 rows x 38 columns]
# chm38
#                       0       1
# 0    number of samples:     667
# 1       number of SNPs:  822301
# 2         AfghanHound01       0
# 3         AfghanHound03       0
# 4         AfghanHound04       0
# ..                  ...     ...
# 664            PER00777       0
# 665            PER00806       0
# 666            PER00816       0
# 667  YorkshireTerrier01       0
# 668  YorkshireTerrier02       0
#
# [669 rows x 2 columns]
# perc_cols:['_Missing%_chr1', '_Missing%_chr2', '_Missing%_chr3', '_Missing%_chr4', '_Missing%_chr5', '_Missing%_chr6', '_Missing%_chr7', '_Missing%_chr8', '_Missing%_chr9', '_Missing%_chr10', '_Missing%_chr11', '_Missing%_chr12', '_Missing%_chr13', '_Missing%_chr14', '_Missing%_chr15', '_Missing%_chr16', '_Missing%_chr17', '_Missing%_chr18', '_Missing%_chr19', '_Missing%_chr20', '_Missing%_chr21', '_Missing%_chr22', '_Missing%_chr23', '_Missing%_chr24', '_Missing%_chr25', '_Missing%_chr26', '_Missing%_chr27', '_Missing%_chr28', '_Missing%_chr29', '_Missing%_chr30', '_Missing%_chr31', '_Missing%_chr32', '_Missing%_chr33', '_Missing%_chr34', '_Missing%_chr35', '_Missing%_chr36', '_Missing%_chr37']
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, _Missing%_chr24, _Missing%_chr25, _Missing%_chr26, _Missing%_chr27, _Missing%_chr28, _Missing%_chr29, _Missing%_chr30, _Missing%_chr31, _Missing%_chr32, _Missing%_chr33, _Missing%_chr34, _Missing%_chr35, _Missing%_chr36, _Missing%_chr37, samples, _Missing%_chr38]
# Index: []
#
# [0 rows x 39 columns]

# %%
df_rm_outer
# Out:
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, _Missing%_chr24, _Missing%_chr25, _Missing%_chr26, _Missing%_chr27, _Missing%_chr28, _Missing%_chr29, _Missing%_chr30, _Missing%_chr31, _Missing%_chr32, _Missing%_chr33, _Missing%_chr34, _Missing%_chr35, _Missing%_chr36, _Missing%_chr37, samples, _Missing%_chr38]
# Index: []
#
# [0 rows x 39 columns]

# %%
df_rm_info = df_rm_outer.merge(metadata[["Name_ID", "Breed/CommonName"]], how="left", left_on="samples", \
                               right_on="Name_ID").drop(columns=["Name_ID"])
df_rm_info
# Out:
# Empty DataFrame
# Columns: [_Missing%_chr1, _Missing%_chr2, _Missing%_chr3, _Missing%_chr4, _Missing%_chr5, _Missing%_chr6, _Missing%_chr7, _Missing%_chr8, _Missing%_chr9, _Missing%_chr10, _Missing%_chr11, _Missing%_chr12, _Missing%_chr13, _Missing%_chr14, _Missing%_chr15, _Missing%_chr16, _Missing%_chr17, _Missing%_chr18, _Missing%_chr19, _Missing%_chr20, _Missing%_chr21, _Missing%_chr22, _Missing%_chr23, _Missing%_chr24, _Missing%_chr25, _Missing%_chr26, _Missing%_chr27, _Missing%_chr28, _Missing%_chr29, _Missing%_chr30, _Missing%_chr31, _Missing%_chr32, _Missing%_chr33, _Missing%_chr34, _Missing%_chr35, _Missing%_chr36, _Missing%_chr37, samples, _Missing%_chr38, Breed/CommonName]
# Index: []
#
# [0 rows x 40 columns]

# %%
# move the Breed Name up front
df_pop=df_rm_info['Breed/CommonName']
df_rm_info.drop(columns=['Breed/CommonName'], inplace=True)
df_rm_info.insert(1,'Population', df_pop)
df_rm_info
# Out:
#        samples              Population  _Missing%_chr1  _Missing%_chr2  \
# 0     PER00167      Labrador Retriever           10.23           13.47
# 1     PER00393       Yorkshire Terrier           31.58           33.70
# 2     PER00438       Yorkshire Terrier           13.21           16.19
# 3     PER00747       Yorkshire Terrier           36.77           37.40
# 4     BAN00150       Yorkshire Terrier             nan           12.06
# 5   ChowChow01               Chow Chow             nan           10.93
# 6     PER00313       Yorkshire Terrier             nan           10.26
# 7        NGSD2  New Guinea Singing Dog             nan             nan
# 8        NGSD3  New Guinea Singing Dog             nan             nan
# 9     PER00152       Yorkshire Terrier             nan             nan
# 10    PER00177      Labrador Retriever             nan             nan
# 11    PER00408       Yorkshire Terrier             nan             nan
# 12    PER00409       Yorkshire Terrier             nan             nan
# 13    PER00484       Yorkshire Terrier             nan             nan
# 14    PER00806       Yorkshire Terrier             nan             nan
#
#     _Missing%_chr3  _Missing%_chr4  _Missing%_chr5  _Missing%_chr6  \
# 0              nan             nan           13.47           11.50
# 1            30.00           29.96           33.61           32.04
# 2            12.25           11.98           13.27           13.38
# 3            37.91           37.97           35.43           36.48
# 4              nan             nan           11.27           10.52
# 5              nan             nan             nan             nan
# 6              nan             nan             nan             nan
# 7              nan             nan             nan             nan
# 8              nan             nan             nan             nan
# 9              nan             nan             nan             nan
# 10             nan             nan             nan             nan
# 11             nan             nan             nan             nan
# 12             nan             nan             nan             nan
# 13             nan             nan             nan             nan
# 14             nan             nan             nan             nan
#
#     _Missing%_chr7  _Missing%_chr8  ...  _Missing%_chr29  _Missing%_chr30  \
# 0              nan             nan  ...              nan            10.69
# 1            29.92           30.09  ...            28.26            31.23
# 2            12.36           14.04  ...            11.81            13.42
# 3            37.27           38.44  ...            39.44            37.22
# 4              nan             nan  ...              nan              nan
# 5              nan             nan  ...              nan              nan
# 6              nan             nan  ...              nan              nan
# 7              nan             nan  ...              nan              nan
# 8              nan             nan  ...              nan              nan
# 9              nan             nan  ...              nan              nan
# 10             nan             nan  ...              nan              nan
# 11             nan             nan  ...              nan              nan
# 12             nan             nan  ...              nan              nan
# 13             nan             nan  ...              nan              nan
# 14             nan             nan  ...              nan              nan
#
#     _Missing%_chr31  _Missing%_chr32  _Missing%_chr33  _Missing%_chr34  \
# 0             11.85              nan              nan              nan
# 1             32.64            26.07            29.21            30.86
# 2             14.75            11.16            11.45            12.42
# 3             40.45            39.57            38.54            37.00
# 4             12.09              nan              nan              nan
# 5             10.03              nan              nan              nan
# 6               nan              nan              nan              nan
# 7               nan              nan              nan              nan
# 8               nan              nan              nan              nan
# 9               nan              nan              nan              nan
# 10              nan              nan              nan              nan
# 11              nan              nan              nan              nan
# 12              nan              nan              nan              nan
# 13              nan              nan              nan              nan
# 14              nan              nan              nan              nan
#
#     _Missing%_chr35  _Missing%_chr36  _Missing%_chr37  _Missing%_chr38
# 0               nan              nan              nan            10.92
# 1             29.76            28.64            29.55            31.41
# 2             11.81            10.13            11.24            12.85
# 3             35.99            37.22            36.39            38.41
# 4               nan              nan              nan            10.43
# 5               nan              nan              nan              nan
# 6               nan              nan              nan              nan
# 7               nan              nan              nan              nan
# 8               nan              nan              nan              nan
# 9               nan              nan              nan              nan
# 10              nan              nan              nan              nan
# 11              nan              nan              nan              nan
# 12              nan              nan              nan              nan
# 13              nan              nan              nan              nan
# 14              nan              nan              nan              nan
#
# [15 rows x 40 columns]

# %%
df_rm_info[['samples', 'Population']].values
# Out:
# array([['PER00167', 'Labrador Retriever'],
#        ['PER00393', 'Yorkshire Terrier'],
#        ['PER00438', 'Yorkshire Terrier'],
#        ['PER00747', 'Yorkshire Terrier'],
#        ['BAN00150', 'Yorkshire Terrier'],
#        ['ChowChow01', 'Chow Chow'],
#        ['PER00313', 'Yorkshire Terrier'],
#        ['NGSD2', 'New Guinea Singing Dog'],
#        ['NGSD3', 'New Guinea Singing Dog'],
#        ['PER00152', 'Yorkshire Terrier'],
#        ['PER00177', 'Labrador Retriever'],
#        ['PER00408', 'Yorkshire Terrier'],
#        ['PER00409', 'Yorkshire Terrier'],
#        ['PER00484', 'Yorkshire Terrier'],
#        ['PER00806', 'Yorkshire Terrier']], dtype=object)

# %%
# save these as the samples to be removed
#form new sample map with these samples removed
df_rm_info.to_csv(''.join([osp.join(out_path, 'dogs'),'/delete_samples.tsv']) , index=None, sep="\t")

# %%
# get the indexes where Sample is in list df_rm_info['samples']
ref_sample_map_keep=ref_sample_map[~(ref_sample_map['Sample'].isin(df_rm_info['samples']))].reset_index(drop=True)

# %%
ref_sample_map[ref_sample_map['Sample'].isin(df_rm_info['samples'])]
# Out:
#          Sample              Population    Superpopulation code
# 154  ChowChow01               Chow Chow               Chow Chow
# 318    PER00167      Labrador Retriever      Labrador Retriever
# 319    PER00177      Labrador Retriever      Labrador Retriever
# 349       NGSD2  New Guinea Singing Dog  New Guinea Singing Dog
# 350       NGSD3  New Guinea Singing Dog  New Guinea Singing Dog
# 600    BAN00150       Yorkshire Terrier       Yorkshire Terrier
# 620    PER00152       Yorkshire Terrier       Yorkshire Terrier
# 625    PER00313       Yorkshire Terrier       Yorkshire Terrier
# 632    PER00393       Yorkshire Terrier       Yorkshire Terrier
# 634    PER00408       Yorkshire Terrier       Yorkshire Terrier
# 635    PER00409       Yorkshire Terrier       Yorkshire Terrier
# 638    PER00438       Yorkshire Terrier       Yorkshire Terrier
# 643    PER00484       Yorkshire Terrier       Yorkshire Terrier
# 659    PER00747       Yorkshire Terrier       Yorkshire Terrier
# 663    PER00806       Yorkshire Terrier       Yorkshire Terrier

# %%
ref_sample_map_keep
# Out:
#                  Sample         Population Superpopulation code
# 0         AfghanHound01       Afghan Hound         Afghan Hound
# 1         AfghanHound03       Afghan Hound         Afghan Hound
# 2         AfghanHound04       Afghan Hound         Afghan Hound
# 3     AiredaleTerrier01   Airedale Terrier     Airedale Terrier
# 4     AiredaleTerrier02   Airedale Terrier     Airedale Terrier
# ..                  ...                ...                  ...
# 647            PER00758  Yorkshire Terrier    Yorkshire Terrier
# 648            PER00777  Yorkshire Terrier    Yorkshire Terrier
# 649            PER00816  Yorkshire Terrier    Yorkshire Terrier
# 650  YorkshireTerrier01  Yorkshire Terrier    Yorkshire Terrier
# 651  YorkshireTerrier02  Yorkshire Terrier    Yorkshire Terrier
#
# [652 rows x 3 columns]

# %%
# ref_sample_map_keep.to_csv(''.join([osp.join(out_path, 'dogs'),'/ref_map_b.txt' ]), index=False, sep="\t", header=None)

# %%
# ref_sample_map_keep.to_csv(''.join([osp.join(out_path, 'dogs'),'/ref_map_b.tsv' ]), index=False, sep="\t")

# %% [markdown]
# # remove anything with MIX, Unknown, Village Dog

# %%
ref_sample_map_keep=pd.read_csv(''.join([osp.join(out_path, 'dogs'),'/ref_map_a.tsv']) , sep="\t")
ref_sample_map_keep
# Out:
#                  Sample         Population Superpopulation code
# 0         AfghanHound01       Afghan Hound         Afghan Hound
# 1         AfghanHound03       Afghan Hound         Afghan Hound
# 2         AfghanHound04       Afghan Hound         Afghan Hound
# 3     AiredaleTerrier01   Airedale Terrier     Airedale Terrier
# 4     AiredaleTerrier02   Airedale Terrier     Airedale Terrier
# ..                  ...                ...                  ...
# 662            PER00777  Yorkshire Terrier    Yorkshire Terrier
# 663            PER00806  Yorkshire Terrier    Yorkshire Terrier
# 664            PER00816  Yorkshire Terrier    Yorkshire Terrier
# 665  YorkshireTerrier01  Yorkshire Terrier    Yorkshire Terrier
# 666  YorkshireTerrier02  Yorkshire Terrier    Yorkshire Terrier
#
# [667 rows x 3 columns]

# %%
rm_samples=ref_sample_map_keep[ref_sample_map_keep['Population'].str.contains(r"\b(?:mix|unknown|village|kunming)\b", case=False)]
rm_samples
# Out:
#                 Sample             Population   Superpopulation code
# 289    VillDog_China10            Kunming Dog            Kunming Dog
# 290    VillDog_China11            Kunming Dog            Kunming Dog
# 291    VillDog_China12            Kunming Dog            Kunming Dog
# 292    VillDog_China13            Kunming Dog            Kunming Dog
# 293    VillDog_China14            Kunming Dog            Kunming Dog
# ..                 ...                    ...                    ...
# 570  VillDog_Vietnam02  Village Dog - Vietnam  Village Dog - Vietnam
# 571  VillDog_Vietnam03  Village Dog - Vietnam  Village Dog - Vietnam
# 572  VillDog_Vietnam04  Village Dog - Vietnam  Village Dog - Vietnam
# 573  VillDog_Vietnam05  Village Dog - Vietnam  Village Dog - Vietnam
# 574  VillDog_Vietnam06  Village Dog - Vietnam  Village Dog - Vietnam
#
# [123 rows x 3 columns]

# %%
rm_samples['Sample'].to_numpy()
# Out:
# array(['VillDog_China10', 'VillDog_China11', 'VillDog_China12',
#        'VillDog_China13', 'VillDog_China14', 'VillDog_China15',
#        'VillDog_China16', 'C3549', 'C750', 'C783', 'CFA.118000', 'GR1078',
#        'MIX_KerryBlueTerrier_Beagle01', 'LA2382', 'A168', 'MI016',
#        'MixedBreed07', 'MixedBreed06', 'VillDog_China17',
#        'VillDog_China18', 'VillDog_China19', 'UnknownBreed09',
#        'KunmingDog01', '406434N', 'BH003', 'JR0034', 'UnknownBreed02',
#        'UnknownBreed03', 'UnknownBreed04', 'UnknownBreed05',
#        'UnknownBreed07', 'UnknownBreed10', 'UnknownBreed11',
#        'UnknownBreed12', 'UnknownBreed13', 'WGS-76N', 'AF14-170_S13',
#        'AF14-259_S12', 'AF14-260_S7', 'AF14-296_S9', 'AF14-297_S10',
#        'AF15-019_S2', 'AF15-074_S4', 'AF15-098_S11', 'NA13-359_S6',
#        'NA14-125_S8', 'NA14-126_S5', 'BAN00143', 'VillDog_Australia01',
#        'VillDog_Borneo01', 'VillDog_Borneo02', 'VillDog_Borneo03',
#        'VillDog_China09', 'VillDog_China01', 'VillDog_China02',
#        'VillDog_China03', 'VillDog_China04', 'VillDog_China05',
#        'VillDog_China06', 'VillDog_China07', 'VillDog_China08',
#        'VillDog_China20', 'VillDog_China21', 'VillDog_China22',
#        'VillDog_China23', 'VillDog_China24', 'VillDog_China25',
#        'VillDog_China26', 'VillDog_China27', 'VillDog_China28',
#        'VillDog_China29', 'VillDog_China30', 'VillDog_China31',
#        'VillDog_China32', 'VillDog_China33', 'VillDog_China34',
#        'VillDog_China35', 'VillDog_China36', 'VillDog_China37',
#        'VillDog_China38', 'VillDog_China39', 'VillDog_China40',
#        'VillDog_China41', 'VillDog_China42', 'VillDog_China43',
#        'VillDog_China44', 'VillDog_China45', 'VillDog_China46',
#        'VillDog_China47', 'VillDog_China48', 'VillDog_China49',
#        'VillDog_China50', 'VillDog_China51', 'VillDog_China52',
#        'VillDog_Egypt01', 'VillDog_Egypt02', 'VillDog_India01',
#        'VillDog_India02', 'VillDog_India03', 'VillDog_India04',
#        'VillDog_India05', 'VillDog_Lebanon01', 'VillDog_Lebanon02',
#        'VillDog_Lebanon03', 'VillDog_Namibia01', 'VillDog_Namibia02',
#        'VillDog_Namibia03', 'VillDog_PapuaNG01', 'VillDog_PapuaNG02',
#        'VillDog_PapuaNG03', 'PT49', 'VillDog_Portugal01',
#        'VillDog_Portugal02', 'VillDog_Qatar01', 'VillDog_Qatar02',
#        'VillDog_Africa01', 'VillDog_Taiwan01', 'VillDog_Vietnam01',
#        'VillDog_Vietnam02', 'VillDog_Vietnam03', 'VillDog_Vietnam04',
#        'VillDog_Vietnam05', 'VillDog_Vietnam06'], dtype=object)

# %%
len(rm_samples)
# Out:
# 123

# %%
ref_sample_map_keep=ref_sample_map_keep[~ref_sample_map_keep['Sample'].isin(rm_samples['Sample'])].reset_index(drop=True)
ref_sample_map_keep
# Out:
#                  Sample         Population Superpopulation code
# 0         AfghanHound01       Afghan Hound         Afghan Hound
# 1         AfghanHound03       Afghan Hound         Afghan Hound
# 2         AfghanHound04       Afghan Hound         Afghan Hound
# 3     AiredaleTerrier01   Airedale Terrier     Airedale Terrier
# 4     AiredaleTerrier02   Airedale Terrier     Airedale Terrier
# ..                  ...                ...                  ...
# 539            PER00777  Yorkshire Terrier    Yorkshire Terrier
# 540            PER00806  Yorkshire Terrier    Yorkshire Terrier
# 541            PER00816  Yorkshire Terrier    Yorkshire Terrier
# 542  YorkshireTerrier01  Yorkshire Terrier    Yorkshire Terrier
# 543  YorkshireTerrier02  Yorkshire Terrier    Yorkshire Terrier
#
# [544 rows x 3 columns]

# %%
ref_sample_map_keep.to_csv(''.join([osp.join(out_path, 'dogs'),'/ref_map_b.txt']), index=None, sep="\t", header=None)
ref_sample_map_keep.to_csv(''.join([osp.join(out_path, 'dogs'),'/ref_map_b.tsv']), index=None, sep="\t")

# %%
# ref_sample_map_keep.to_csv(''.join([osp.join(out_path, 'dogs'),'/ref_map_c.txt']), index=None, sep="\t", header=None)
# ref_sample_map_keep.to_csv(''.join([osp.join(out_path, 'dogs'),'/ref_map_c.tsv']), index=None, sep="\t")

# %% [markdown]
# # Make granular pop for expt1.txt

# %%
ref_map_expt1=pd.read_csv(osp.join(in_path,"dogs/expt1.txt"), sep="\t", header=None)
ref_map_expt1
# Out:
#                       0          1
# 0            140447_S11  Retriever
# 1             149323_S6  Retriever
# 2             152721_S5  Retriever
# 3             160822_S4  Retriever
# 4             164612_S9  Retriever
# ..                  ...        ...
# 242       WolfTibetan07       Wolf
# 243       WolfTibetan08       Wolf
# 244          XiasiDog01       East
# 245  YorkshireTerrier01    Terrier
# 246  YorkshireTerrier02    Terrier
#
# [247 rows x 2 columns]

# %%
ref_map_expt1=ref_map_expt1.merge(metadata[['Name_ID', 'Breed/CommonName']], \
                                  left_on=0, right_on="Name_ID", how="left")
ref_map_expt1.drop(columns=["Name_ID"], inplace=True)

# %%
ref_map_expt1.rename(columns={0:'Sample', 1:'Superpopulation code', 'Breed/CommonName':'Population'}, inplace=True)

# %%
ref_map_expt1_w_wolf_coyote = ref_map_expt1.to_csv(''.join([osp.join(out_path, 'dogs'),'/ref_map_expt1_w_wolf_coyote.tsv' ]),\
                                                   index=False, sep="\t")

# %%
ref_map_expt1=ref_map_expt1[~ref_map_expt1["Superpopulation code"].isin(["Wolf", "Coyote"])]

# %%
ref_map_expt1
# Out:
#                       Sample Superpopulation code                   Population
# 0                 140447_S11            Retriever             Golden Retriever
# 1                  149323_S6            Retriever           Labrador Retriever
# 2                  152721_S5            Retriever           Labrador Retriever
# 3                  160822_S4            Retriever           Labrador Retriever
# 4                  164612_S9            Retriever             Golden Retriever
# ..                       ...                  ...                          ...
# 203  WestHighlandWhiteTerr09              Terrier  West Highland White Terrier
# 204                Whippet01            Greyhound                      Whippet
# 244               XiasiDog01                 East                    Xiasi Dog
# 245       YorkshireTerrier01              Terrier            Yorkshire Terrier
# 246       YorkshireTerrier02              Terrier            Yorkshire Terrier
#
# [198 rows x 3 columns]

# %%
# ref_map_expt1.to_csv(''.join([osp.join(out_path, 'dogs'),'/ref_map_expt1.tsv' ]), index=False, sep="\t")

# %% [markdown]
# ## Beyond this point, nb NOT Valid anymore

# %% [markdown]
# # find the problem samples for sample map d

# %%
import os.path as osp
start_chr=31
end_chr=38
pd.options.display.float_format = '{:.2f}'.format
for i in range(start_chr, end_chr+1):
    print(f"chm{i}")
    df_chr = pd.read_csv(''.join([osp.join(out_path,'dogs', 'sm_d/chr'+str(i)),'/chr'+str(i)+'_nMissing.txt']), sep="\t", header=None)
    print(df_chr)
    df_chr_missing = df_chr[1:].copy()
    df_chr_missing.columns=['samples', 'nMissing']
    df_chr_missing['_Missing%'] = df_chr_missing['nMissing']*100/df_chr.iloc[0,1]
    
    df_rm_samples = df_chr_missing[df_chr_missing['_Missing%']>10]
    perc_cols=[col for col in df_rm_outer.columns if '_Missing%' in col] if i>start_chr else '_Missing%'
    print(f"perc_cols:{perc_cols}")
    df_rm_outer = df_rm_outer[['samples', *perc_cols]].merge(df_rm_samples[['samples', '_Missing%']], \
                    how="outer", on="samples") if i>start_chr else df_rm_samples[['samples', '_Missing%']]
    df_rm_outer.rename(columns={'_Missing%':'_Missing%_chr'+str(i)}, inplace=True)
    print(df_rm_outer)
# Out:
# chm31
#                       0        1
# 0       number of SNPs:  1304523
# 1         AfghanHound01    18554
# 2         AfghanHound03    55787
# 3         AfghanHound04    30497
# 4     AiredaleTerrier01    68991
# ..                  ...      ...
# 525            PER00758    22347
# 526            PER00777    23736
# 527            PER00816    23282
# 528  YorkshireTerrier01    17049
# 529  YorkshireTerrier02    17810
#
# [530 rows x 2 columns]
# perc_cols:_Missing%
#                samples  _Missing%_chr31
# 110            Boxer01            37.49
# 365              Pug01            18.26
# 366              Pug02            19.43
# 368              Pug04            23.78
# 416     SpanishGalgo01            12.94
# 427  SwedishLapphund01            10.61
# 441          Tornjak01            17.10
# chm32
#                       0        1
# 0       number of SNPs:  1222521
# 1         AfghanHound01    16947
# 2         AfghanHound03    50660
# 3         AfghanHound04    27949
# 4     AiredaleTerrier01    31145
# ..                  ...      ...
# 525            PER00758    20109
# 526            PER00777    21442
# 527            PER00816    20209
# 528  YorkshireTerrier01    15703
# 529  YorkshireTerrier02    19735
#
# [530 rows x 2 columns]
# perc_cols:['_Missing%_chr31']
#              samples  _Missing%_chr31  _Missing%_chr32
# 0            Boxer01            37.49           100.00
# 1              Pug01            18.26              nan
# 2              Pug02            19.43              nan
# 3              Pug04            23.78            10.53
# 4     SpanishGalgo01            12.94              nan
# 5  SwedishLapphund01            10.61              nan
# 6          Tornjak01            17.10              nan
# chm33
#                       0       1
# 0       number of SNPs:  981145
# 1         AfghanHound01   14971
# 2         AfghanHound03   41366
# 3         AfghanHound04   24687
# 4     AiredaleTerrier01   35602
# ..                  ...     ...
# 525            PER00758   19860
# 526            PER00777   19308
# 527            PER00816   17664
# 528  YorkshireTerrier01   13640
# 529  YorkshireTerrier02   17409
#
# [530 rows x 2 columns]
# perc_cols:['_Missing%_chr31', '_Missing%_chr32']
#              samples  _Missing%_chr31  _Missing%_chr32  _Missing%_chr33
# 0            Boxer01            37.49           100.00           100.00
# 1              Pug01            18.26              nan            12.98
# 2              Pug02            19.43              nan            14.26
# 3              Pug04            23.78            10.53            18.97
# 4     SpanishGalgo01            12.94              nan              nan
# 5  SwedishLapphund01            10.61              nan              nan
# 6          Tornjak01            17.10              nan            13.34
# chm34
#                       0        1
# 0       number of SNPs:  1401538
# 1         AfghanHound01    20116
# 2         AfghanHound03    51687
# 3         AfghanHound04    28810
# 4     AiredaleTerrier01    44684
# ..                  ...      ...
# 525            PER00758    25793
# 526            PER00777    22946
# 527            PER00816    23284
# 528  YorkshireTerrier01    19774
# 529  YorkshireTerrier02    18599
#
# [530 rows x 2 columns]
# perc_cols:['_Missing%_chr31', '_Missing%_chr32', '_Missing%_chr33']
#              samples  _Missing%_chr31  _Missing%_chr32  _Missing%_chr33  \
# 0            Boxer01            37.49           100.00           100.00
# 1              Pug01            18.26              nan            12.98
# 2              Pug02            19.43              nan            14.26
# 3              Pug04            23.78            10.53            18.97
# 4     SpanishGalgo01            12.94              nan              nan
# 5  SwedishLapphund01            10.61              nan              nan
# 6          Tornjak01            17.10              nan            13.34
#
#    _Missing%_chr34
# 0           100.00
# 1            14.87
# 2            16.48
# 3            23.28
# 4              nan
# 5              nan
# 6            14.44
# chm35
#                       0       1
# 0       number of SNPs:  871160
# 1         AfghanHound01   12533
# 2         AfghanHound03   32634
# 3         AfghanHound04   20060
# 4     AiredaleTerrier01   27951
# ..                  ...     ...
# 525            PER00758   15817
# 526            PER00777   15423
# 527            PER00816   14615
# 528  YorkshireTerrier01   12273
# 529  YorkshireTerrier02   11835
#
# [530 rows x 2 columns]
# perc_cols:['_Missing%_chr31', '_Missing%_chr32', '_Missing%_chr33', '_Missing%_chr34']
#              samples  _Missing%_chr31  _Missing%_chr32  _Missing%_chr33  \
# 0            Boxer01            37.49           100.00           100.00
# 1              Pug01            18.26              nan            12.98
# 2              Pug02            19.43              nan            14.26
# 3              Pug04            23.78            10.53            18.97
# 4     SpanishGalgo01            12.94              nan              nan
# 5  SwedishLapphund01            10.61              nan              nan
# 6          Tornjak01            17.10              nan            13.34
#
#    _Missing%_chr34  _Missing%_chr35
# 0           100.00           100.00
# 1            14.87            14.17
# 2            16.48            16.06
# 3            23.28            24.09
# 4              nan              nan
# 5              nan              nan
# 6            14.44            14.70
# chm36
#                       0       1
# 0       number of SNPs:  912303
# 1         AfghanHound01   13244
# 2         AfghanHound03   36446
# 3         AfghanHound04   20375
# 4     AiredaleTerrier01   26292
# ..                  ...     ...
# 525            PER00758   14913
# 526            PER00777   14992
# 527            PER00816   14864
# 528  YorkshireTerrier01   11695
# 529  YorkshireTerrier02   12853
#
# [530 rows x 2 columns]
# perc_cols:['_Missing%_chr31', '_Missing%_chr32', '_Missing%_chr33', '_Missing%_chr34', '_Missing%_chr35']
#              samples  _Missing%_chr31  _Missing%_chr32  _Missing%_chr33  \
# 0            Boxer01            37.49           100.00           100.00
# 1              Pug01            18.26              nan            12.98
# 2              Pug02            19.43              nan            14.26
# 3              Pug04            23.78            10.53            18.97
# 4     SpanishGalgo01            12.94              nan              nan
# 5  SwedishLapphund01            10.61              nan              nan
# 6          Tornjak01            17.10              nan            13.34
#
#    _Missing%_chr34  _Missing%_chr35  _Missing%_chr36
# 0           100.00           100.00           100.00
# 1            14.87            14.17            10.16
# 2            16.48            16.06            11.35
# 3            23.28            24.09            15.88
# 4              nan              nan              nan
# 5              nan              nan              nan
# 6            14.44            14.70            11.22
# chm37
#                       0       1
# 0       number of SNPs:  977540
# 1         AfghanHound01   12319
# 2         AfghanHound03   34925
# 3         AfghanHound04   19510
# 4     AiredaleTerrier01   30580
# ..                  ...     ...
# 525            PER00758   15358
# 526            PER00777   15221
# 527            PER00816   15167
# 528  YorkshireTerrier01   11370
# 529  YorkshireTerrier02   12649
#
# [530 rows x 2 columns]
# perc_cols:['_Missing%_chr31', '_Missing%_chr32', '_Missing%_chr33', '_Missing%_chr34', '_Missing%_chr35', '_Missing%_chr36']
#              samples  _Missing%_chr31  _Missing%_chr32  _Missing%_chr33  \
# 0            Boxer01            37.49           100.00           100.00
# 1              Pug01            18.26              nan            12.98
# 2              Pug02            19.43              nan            14.26
# 3              Pug04            23.78            10.53            18.97
# 4     SpanishGalgo01            12.94              nan              nan
# 5  SwedishLapphund01            10.61              nan              nan
# 6          Tornjak01            17.10              nan            13.34
#
#    _Missing%_chr34  _Missing%_chr35  _Missing%_chr36  _Missing%_chr37
# 0           100.00           100.00           100.00           100.00
# 1            14.87            14.17            10.16            14.18
# 2            16.48            16.06            11.35            15.73
# 3            23.28            24.09            15.88            21.49
# 4              nan              nan              nan              nan
# 5              nan              nan              nan              nan
# 6            14.44            14.70            11.22            13.87
# chm38
#                       0       1
# 0       number of SNPs:  822301
# 1         AfghanHound01   15245
# 2         AfghanHound03   36130
# 3         AfghanHound04   20159
# 4     AiredaleTerrier01   33399
# ..                  ...     ...
# 525            PER00758   14164
# 526            PER00777   15293
# 527            PER00816   14243
# 528  YorkshireTerrier01   11295
# 529  YorkshireTerrier02   11865
#
# [530 rows x 2 columns]
# perc_cols:['_Missing%_chr31', '_Missing%_chr32', '_Missing%_chr33', '_Missing%_chr34', '_Missing%_chr35', '_Missing%_chr36', '_Missing%_chr37']
#              samples  _Missing%_chr31  _Missing%_chr32  _Missing%_chr33  \
# 0            Boxer01            37.49           100.00           100.00
# 1              Pug01            18.26              nan            12.98
# 2              Pug02            19.43              nan            14.26
# 3              Pug04            23.78            10.53            18.97
# 4     SpanishGalgo01            12.94              nan              nan
# 5  SwedishLapphund01            10.61              nan              nan
# 6          Tornjak01            17.10              nan            13.34
#
#    _Missing%_chr34  _Missing%_chr35  _Missing%_chr36  _Missing%_chr37  \
# 0           100.00           100.00           100.00           100.00
# 1            14.87            14.17            10.16            14.18
# 2            16.48            16.06            11.35            15.73
# 3            23.28            24.09            15.88            21.49
# 4              nan              nan              nan              nan
# 5              nan              nan              nan              nan
# 6            14.44            14.70            11.22            13.87
#
#    _Missing%_chr38
# 0           100.00
# 1            17.31
# 2            19.35
# 3            25.88
# 4            10.40
# 5              nan
# 6            16.94
# /share/software/user/open/py-pandas/1.0.3_py36/lib/python3.6/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_rm_outer
# Out:
#              samples  _Missing%_chr31  _Missing%_chr32  _Missing%_chr33  \
# 0            Boxer01            37.49           100.00           100.00
# 1              Pug01            18.26              nan            12.98
# 2              Pug02            19.43              nan            14.26
# 3              Pug04            23.78            10.53            18.97
# 4     SpanishGalgo01            12.94              nan              nan
# 5  SwedishLapphund01            10.61              nan              nan
# 6          Tornjak01            17.10              nan            13.34
#
#    _Missing%_chr34  _Missing%_chr35  _Missing%_chr36  _Missing%_chr37  \
# 0           100.00           100.00           100.00           100.00
# 1            14.87            14.17            10.16            14.18
# 2            16.48            16.06            11.35            15.73
# 3            23.28            24.09            15.88            21.49
# 4              nan              nan              nan              nan
# 5              nan              nan              nan              nan
# 6            14.44            14.70            11.22            13.87
#
#    _Missing%_chr38
# 0           100.00
# 1            17.31
# 2            19.35
# 3            25.88
# 4            10.40
# 5              nan
# 6            16.94

# %%
df_rm_info = df_rm_outer.merge(metadata[["Name_ID", "Breed/CommonName"]], how="left", left_on="samples", \
                               right_on="Name_ID").drop(columns=["Name_ID"])
df_rm_info
# Out:
#              samples  _Missing%_chr31  _Missing%_chr32  _Missing%_chr33  \
# 0            Boxer01            37.49           100.00           100.00
# 1              Pug01            18.26              nan            12.98
# 2              Pug02            19.43              nan            14.26
# 3              Pug04            23.78            10.53            18.97
# 4     SpanishGalgo01            12.94              nan              nan
# 5  SwedishLapphund01            10.61              nan              nan
# 6          Tornjak01            17.10              nan            13.34
#
#    _Missing%_chr34  _Missing%_chr35  _Missing%_chr36  _Missing%_chr37  \
# 0           100.00           100.00           100.00           100.00
# 1            14.87            14.17            10.16            14.18
# 2            16.48            16.06            11.35            15.73
# 3            23.28            24.09            15.88            21.49
# 4              nan              nan              nan              nan
# 5              nan              nan              nan              nan
# 6            14.44            14.70            11.22            13.87
#
#    _Missing%_chr38  Breed/CommonName
# 0           100.00             Boxer
# 1            17.31               Pug
# 2            19.35               Pug
# 3            25.88               Pug
# 4            10.40     Spanish Galgo
# 5              nan  Swedish Lapphund
# 6            16.94           Tornjak

# %%
# move the Breed Name up front
df_pop=df_rm_info['Breed/CommonName']
df_rm_info.drop(columns=['Breed/CommonName'], inplace=True)
df_rm_info.insert(1,'Population', df_pop)
df_rm_info
# Out:
#              samples        Population  _Missing%_chr31  _Missing%_chr32  \
# 0            Boxer01             Boxer            37.49           100.00
# 1              Pug01               Pug            18.26              nan
# 2              Pug02               Pug            19.43              nan
# 3              Pug04               Pug            23.78            10.53
# 4     SpanishGalgo01     Spanish Galgo            12.94              nan
# 5  SwedishLapphund01  Swedish Lapphund            10.61              nan
# 6          Tornjak01           Tornjak            17.10              nan
#
#    _Missing%_chr33  _Missing%_chr34  _Missing%_chr35  _Missing%_chr36  \
# 0           100.00           100.00           100.00           100.00
# 1            12.98            14.87            14.17            10.16
# 2            14.26            16.48            16.06            11.35
# 3            18.97            23.28            24.09            15.88
# 4              nan              nan              nan              nan
# 5              nan              nan              nan              nan
# 6            13.34            14.44            14.70            11.22
#
#    _Missing%_chr37  _Missing%_chr38
# 0           100.00           100.00
# 1            14.18            17.31
# 2            15.73            19.35
# 3            21.49            25.88
# 4              nan            10.40
# 5              nan              nan
# 6            13.87            16.94

# %%
df_rm_info[['samples', 'Population']].values
# Out:
# array([['Boxer01', 'Boxer'],
#        ['Pug01', 'Pug'],
#        ['Pug02', 'Pug'],
#        ['Pug04', 'Pug'],
#        ['SpanishGalgo01', 'Spanish Galgo'],
#        ['SwedishLapphund01', 'Swedish Lapphund'],
#        ['Tornjak01', 'Tornjak']], dtype=object)

# %%
# save these as the samples to be removed
#form new sample map with these samples removed
df_rm_info.to_csv(''.join([osp.join(out_path, 'dogs'),'/delete_samples_frm_d.tsv']) , index=None, sep="\t")

# %%
# get the indexes where Sample is in list df_rm_info['samples']
ref_sample_map_e=ref_sample_map_keep[~(ref_sample_map_keep['Sample'].isin(df_rm_info['samples']))].reset_index(drop=True)

# %%
ref_sample_map_e
# Out:
#                  Sample         Population Superpopulation code
# 0         AfghanHound01       Afghan Hound         Afghan Hound
# 1         AfghanHound03       Afghan Hound         Afghan Hound
# 2         AfghanHound04       Afghan Hound         Afghan Hound
# 3     AiredaleTerrier01   Airedale Terrier     Airedale Terrier
# 4     AiredaleTerrier02   Airedale Terrier     Airedale Terrier
# ..                  ...                ...                  ...
# 517            PER00758  Yorkshire Terrier    Yorkshire Terrier
# 518            PER00777  Yorkshire Terrier    Yorkshire Terrier
# 519            PER00816  Yorkshire Terrier    Yorkshire Terrier
# 520  YorkshireTerrier01  Yorkshire Terrier    Yorkshire Terrier
# 521  YorkshireTerrier02  Yorkshire Terrier    Yorkshire Terrier
#
# [522 rows x 3 columns]

# %%
ref_sample_map_e.to_csv(''.join([osp.join(out_path, 'dogs'),'/ref_map_e.txt']), index=None, sep="\t", header=None)
ref_sample_map_e.to_csv(''.join([osp.join(out_path, 'dogs'),'/ref_map_e.tsv']), index=None, sep="\t")
