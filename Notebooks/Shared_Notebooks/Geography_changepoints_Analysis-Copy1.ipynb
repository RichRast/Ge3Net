# %% [markdown]
# <b>Hyperparameters</b>:
# <br><b>win_tol</b>: window tolerance within which if a method detected cp, count that as true changepoint detected
# <br>win_tol=2
# <br>For BOCD: <b>run_length_threshold</b> - the change in run_length that constitutes a changepoint, for example if run_length_threshold is set to 4, then if run length drops by 4 or more, then that constitutes a changepoint
# <br>For gradient based: <b>gradient_threshold</b>: the threshold above which a change in gradient constitutes a changepoint.
# <br>For MC_dropout: <b>mc_dropout_threshold</b>: the threshold above which a change in variance in any of the output dimensions constitutes a changepoint
# <br>
# <br> <b>If TP=FP=0, Precision=1 rather than 0 and if TP=FN=0, then Recall=1 rather than 0
# <br> zero division is taken as 1 and not 0 for Precision and Recall</b>
# <br> example: true_cps = [3, 31, 250, 273], pred_cps = [30, 31, 249, 250, 272, 300]
# <br> TP = 3, FP = 1, FN = 1, TN = 317-5 = 312
# <br> true changepoint 3 could not be detected but the rest were detected within the window tolerance
# <br> false changepoint 300 was detected
# <br>
# <br>Precision = TP/(TP+FP)
# <br>Recall or A_cp = TP/(TP+FN)
# <br>A_cp = Accuracy for detecting changepoints (minority class)
# <br>Accuracy = (TP+TN)/(TP+TN+FP+FN)
# <br>A_major or A_no_cp = TN/(TN+FP)
# <br>A_major or A_no_cp = Accuracy for detecting points that are not changepoints (majority class)
# <br>Balanced_Accuracy = 1/2*(A_cp+A_major)

# %%
import torch
import sys
import os
import os.path as osp
import pandas as pd
import numpy as np
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import ticker
import matplotlib as mpl
from   matplotlib.colors import LogNorm
from sklearn.metrics import precision_recall_curve, recall_score, precision_score, \
balanced_accuracy_score, accuracy_score, auc
from sklearn import metrics

# %%
root_dir = "/home/users/richras/Ge2Net_Repo"
os.chdir(root_dir)

# %%
# !./ini.sh
# Out:
# /bin/sh: ./ini.sh: Permission denied

# %%
os.environ['USER_PATH']='/home/users/richras/Ge2Net_Repo'
os.environ['USER_SCRATCH_PATH']="/scratch/users/richras"
os.environ['IN_PATH']='/scratch/groups/cdbustam/richras/data_in'
os.environ['OUT_PATH']='/scratch/groups/cdbustam/richras/data_out'
os.environ['LOG_PATH']='/scratch/groups/cdbustam/richras/logs/'

# %%
# %load_ext autoreload
# %autoreload 2
from src.utils.dataUtil import load_path, save_file, vcf2npy, get_recomb_rate, interpolate_genetic_pos, form_windows
from src.utils.modelUtil import Params, load_model
from src.utils.decorators import timer
from src.models import AuxiliaryTask, LSTM, Attention, BasicBlock, Model_A, Model_B, Model_C, BOCD
from src.models.distributions import Multivariate_Gaussian
from src.main.evaluation import eval_cp_batch, reportChangePointMetrics, t_prMetrics, cpMethod, eval_cp_matrix, \
getCpPred
import inference

# %% [markdown]
# # load the model and use valid data to choose hyperpparams for the different cp methods

# %%
# Specify the dataset to be evaluated
# chm22 pca full dataset and model
labels_path = osp.join(os.environ['OUT_PATH'],'humans/labels/data_id_1_pca')
data_path = osp.join(os.environ['OUT_PATH'],'humans/labels/data_id_1_pca')
models_path=osp.join(os.environ['OUT_PATH'],'humans/training/Model_Q_exp_id_1_data_id_1_pca/') 
dataset_type='valid'

# %%
config={}
config['data.labels']=labels_path 
config['data.dir']=data_path 
config['models.dir']=models_path
config['data.dataset_type']=dataset_type
config['cuda']='cuda'
config['model.loadBest']=True
json_path = osp.join(config['models.dir'], 'params.yaml')
assert osp.isfile(json_path), "No json configuration file found at {}".format(json_path)
params = Params(json_path)
params.rtnOuts=True
params.mc_dropout=True
params.mc_samples=100
params.cp_tol=0
params.evalCp=True
params.evalBalancedGcd=True
params.evalExtraMainLosses=True
# params.cp_pos_weight=10.0
params.pretrained=False
results, valid_dataset, _, modelStats=inference.main(config, params)
# Out:
# INFO: __init__:src.main.dataset: Loading valid Dataset
# INFO: __init__:src.main.dataset:Loading gen 0
#  device used: cuda
# Loading the datasets...
# INFO: __init__:src.main.dataset: snps data: (1250, 317410)
# INFO: __init__:src.main.dataset: y_labels data :(1250, 317410)
# INFO: __init__:src.main.dataset:Loading gen 2
# INFO: __init__:src.main.dataset: snps data: (800, 317410)
# INFO: __init__:src.main.dataset: y_labels data :(800, 317410)
# INFO: __init__:src.main.dataset:Loading gen 4
# INFO: __init__:src.main.dataset: snps data: (800, 317410)
# INFO: __init__:src.main.dataset: y_labels data :(800, 317410)
# INFO: __init__:src.main.dataset:Loading gen 8
# INFO: __init__:src.main.dataset: snps data: (800, 317410)
# INFO: __init__:src.main.dataset: y_labels data :(800, 317410)
# INFO: transform_data:src.main.dataset:Transforming the data
# Finished 'mapping_func' in 0.4285 secs
# Finished 'pop_mapping' in 0.1472 secs
# Finished 'pop_mapping' in 0.1426 secs
# Finished 'transform_data' in 41.8943 secs
# Finished '__init__' in 103.7952 secs
# Parameter count for model AuxNetwork:31747503
# Parameter count for model TransformerModel:107528
# Parameter count for model BiRNN:34499
# Parameter count for model logits_Block:2289
# Total parameters:31891819
# device in load model:None
# Finished 'load_model' in 0.4353 secs
# best val loss metrics : {'loss_main': 0.32982670098526423, 'loss_aux': 0.8378495132421891, 'gcd': None, 'mse': 0.17319945671879727, 'smooth_l1': 0.08350094807714122, 'weighted_loss': 0.32982670098526423}
# at epoch : 131
# train loss metrics: {'loss_main': 0.31123373579025687, 'loss_aux': 0.7249774828171883, 'gcd': None, 'mse': 0.09206160483954577, 'smooth_l1': 0.045924477757158993, 'weighted_loss': 0.31123373579025687}
# best val cp metrics : {'loss_cp': 0.2588518878027973, 'prMetrics': OrderedDict([('Precision', array(0.36076843)), ('Recall', array(0.73315897)), ('Accuracy', array(0.97878484)), ('A_major', array(0.98215835)), ('BalancedAccuracy', 0.8576586575591449)])}
# train cp metrics: {'loss_cp': 0.11726000587889517, 'prMetrics': OrderedDict([('Precision', array(0.60661248)), ('Recall', array(0.8953649)), ('Accuracy', array(0.99471769)), ('A_major', array(0.99548947)), ('BalancedAccuracy', 0.9454271888595733)])}
# best val sp metrics : None
# train sp metrics: None
# best val balanced gcd metrics : None
# train balanced gcd metrics: None
# is the model on cuda? : True
# Finished 'batchLoopValid' in 145.1604 secs
# Finished 'main' in 251.5888 secs

# %%
results.t_out.coord_main=results.t_out.coord_main.mean(0)

# %%
results.t_out.coord_main.shape
# Out:
# (3650, 317, 3)

# %%
results.t_accr, results.t_cp_accr
# Out:
# ({'gcd': None,
#   'loss_aux': 0.8462355809223888,
#   'loss_main': 0.35087459588771014,
#   'mse': 0.17059925746476762,
#   'smooth_l1': 0.08312591068747029,
#   'weighted_loss': 0.35087459588771014},
#  {'loss_cp': 0.1911115868986593,
#   'prMetrics': OrderedDict([('Precision', array(0.29551577)),
#                ('Recall', array(0.70831751)),
#                ('Accuracy', array(0.98648114)),
#                ('A_major', array(0.98839317)),
#                ('BalancedAccuracy', 0.8483553394038026)])})

# %%
@timer
def prMetricsByThresh(method_name, cp_pred_raw, cp_target, steps, minThresh, maxThresh, win_tol=2, byWindows=False):
    increment = (maxThresh - minThresh)/steps
    df=pd.DataFrame(columns=list(t_prMetrics._fields)+['thresh'])
    for thresh in np.arange(minThresh, maxThresh + increment, increment):
        prMetrics, cp_pred = reportChangePointMetrics(method_name, cp_pred_raw, cp_target, thresh, win_tol)
        if byWindows: 
            prMetrics={}
            prMetrics['Precision']=precision_score(cp_target.flatten(), cp_pred.flatten())
            prMetrics['Recall']=recall_score(cp_target.flatten(), cp_pred.flatten())
            prMetrics['BalancedAccuracy']=balanced_accuracy_score(cp_target.flatten(), cp_pred.flatten())
            prMetrics['Accuracy']=accuracy_score(cp_target.flatten(), cp_pred.flatten())
            prMetrics['A_major']=(2*prMetrics['BalancedAccuracy'])-prMetrics['Recall']
        prMetrics['thresh']=thresh
        prMetrics['F1']=2*prMetrics['Precision']*prMetrics['Recall']/(prMetrics['Precision']+prMetrics['Recall'])
        df=df.append(prMetrics, ignore_index=True)
    return df

# %% [markdown]
# # neural network, choose the threshold for logits

# %%
df_nn=prMetricsByThresh(cpMethod.neural_network.name, torch.tensor(results.t_out.cp_logits).float(), \
                        torch.tensor(valid_dataset.data['cps']).unsqueeze(2).float(), 20, 0, 0.85)
df_nn.style.background_gradient(cmap="Blues")
# Out:
# Finished 'prMetricsByThresh' in 10.8285 secs
# <style  type="text/css" >
#     #T_456fb27a_f044_11ec_9bae_64006ac0923arow0_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow0_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow0_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow1_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow1_col5 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow1_col6 {
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow2_col4 {
#             background-color:  #08316d;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow2_col5 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow2_col6 {
#             background-color:  #dae8f6;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow3_col4 {
#             background-color:  #08326e;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow3_col5 {
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow3_col6 {
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow4_col4 {
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow4_col5 {
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow4_col6 {
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow5_col4 {
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow5_col5 {
#             background-color:  #c6dbef;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow5_col6 {
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow6_col4 {
#             background-color:  #083573;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow6_col5 {
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow6_col6 {
#             background-color:  #5fa6d1;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow7_col4 {
#             background-color:  #083776;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow7_col5 {
#             background-color:  #a6cee4;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow7_col6 {
#             background-color:  #529dcc;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow8_col4 {
#             background-color:  #083979;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow8_col5 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow8_col6 {
#             background-color:  #4695c8;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow9_col4 {
#             background-color:  #083a7a;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow9_col5 {
#             background-color:  #7fb9da;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow9_col6 {
#             background-color:  #3e8ec4;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow10_col4 {
#             background-color:  #083c7d;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow10_col5 {
#             background-color:  #6aaed6;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow10_col6 {
#             background-color:  #3888c1;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow11_col4 {
#             background-color:  #083d7f;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow11_col5 {
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow11_col6 {
#             background-color:  #3282be;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow12_col4 {
#             background-color:  #084082;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow12_col5 {
#             background-color:  #4a98c9;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow12_col6 {
#             background-color:  #2c7cba;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow13_col4 {
#             background-color:  #084184;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow13_col5 {
#             background-color:  #3b8bc2;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow13_col6 {
#             background-color:  #2474b7;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow14_col4 {
#             background-color:  #084387;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow14_col5 {
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow14_col6 {
#             background-color:  #1e6db2;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow15_col4 {
#             background-color:  #08478d;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow15_col5 {
#             background-color:  #2070b4;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow15_col6 {
#             background-color:  #1764ab;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow16_col4 {
#             background-color:  #084e98;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow16_col5 {
#             background-color:  #1764ab;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow16_col6 {
#             background-color:  #0e58a2;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow17_col4 {
#             background-color:  #0e58a2;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow17_col5 {
#             background-color:  #0d57a1;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow17_col6 {
#             background-color:  #084488;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow18_col4 {
#             background-color:  #1561a9;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow18_col5 {
#             background-color:  #084a91;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow18_col6 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow19_col4 {
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow19_col5 {
#             background-color:  #083c7d;
#             color:  #f1f1f1;
#         }    #T_456fb27a_f044_11ec_9bae_64006ac0923arow19_col6 {
#             background-color:  #08316d;

# %%
nnThresh=0.65

# %% [markdown]
# # gradient method, choose the threshold for gradient difference in predictions

# %%
df_grad=prMetricsByThresh(cpMethod.gradient.name, torch.tensor(results.t_out.coord_main).float(), \
                        torch.tensor(valid_dataset.data['cps']).unsqueeze(2).float(), 20, 0,1)
df_grad.style.background_gradient(cmap="Blues")
# Out:
# Finished 'prMetricsByThresh' in 8.5518 secs
# <style  type="text/css" >
#     #T_4a99adb4_f044_11ec_9bae_64006ac0923arow0_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow0_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow0_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow1_col4 {
#             background-color:  #084387;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow1_col5 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow1_col6 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow2_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow2_col5 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow2_col6 {
#             background-color:  #c6dbef;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow3_col4 {
#             background-color:  #083674;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow3_col5 {
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow3_col6 {
#             background-color:  #82bbdb;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow4_col4 {
#             background-color:  #084285;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow4_col5 {
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow4_col6 {
#             background-color:  #519ccc;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow5_col4 {
#             background-color:  #084d96;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow5_col5 {
#             background-color:  #c6dbef;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow5_col6 {
#             background-color:  #3080bd;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow6_col4 {
#             background-color:  #0e59a2;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow6_col5 {
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow6_col6 {
#             background-color:  #1967ad;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow7_col4 {
#             background-color:  #1764ab;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow7_col5 {
#             background-color:  #a6cee4;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow7_col6 {
#             background-color:  #08509b;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow8_col4 {
#             background-color:  #2171b5;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow8_col5 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow8_col6 {
#             background-color:  #083c7d;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow9_col4 {
#             background-color:  #3181bd;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow9_col5 {
#             background-color:  #7fb9da;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow9_col6 {
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow10_col4 {
#             background-color:  #3e8ec4;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow10_col5 {
#             background-color:  #6aaed6;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow10_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow11_col4 {
#             background-color:  #519ccc;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow11_col5 {
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow11_col6 {
#             background-color:  #08326e;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow12_col4 {
#             background-color:  #61a7d2;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow12_col5 {
#             background-color:  #4a98c9;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow12_col6 {
#             background-color:  #083877;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow13_col4 {
#             background-color:  #77b5d9;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow13_col5 {
#             background-color:  #3b8bc2;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow13_col6 {
#             background-color:  #08468b;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow14_col4 {
#             background-color:  #8dc1dd;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow14_col5 {
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow14_col6 {
#             background-color:  #0c56a0;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow15_col4 {
#             background-color:  #a1cbe2;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow15_col5 {
#             background-color:  #2070b4;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow15_col6 {
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow16_col4 {
#             background-color:  #aed1e7;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow16_col5 {
#             background-color:  #1764ab;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow16_col6 {
#             background-color:  #2575b7;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow17_col4 {
#             background-color:  #bcd7eb;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow17_col5 {
#             background-color:  #0d57a1;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow17_col6 {
#             background-color:  #3787c0;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow18_col4 {
#             background-color:  #c7dcef;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow18_col5 {
#             background-color:  #084a91;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow18_col6 {
#             background-color:  #4a98c9;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow19_col4 {
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow19_col5 {
#             background-color:  #083c7d;
#             color:  #f1f1f1;
#         }    #T_4a99adb4_f044_11ec_9bae_64006ac0923arow19_col6 {
#             background-color:  #61a7d2;

# %%
gradThresh=0.15

# %% [markdown]
# # mc dropout variance, choose the threshold for difference in variance

# %%
df_var=prMetricsByThresh(cpMethod.mc_dropout.name, torch.tensor(results.t_out.y_var).float(), \
                        torch.tensor(valid_dataset.data['cps']).unsqueeze(2).float(), 20, 0,0.5)
df_var.style.background_gradient(cmap="Blues")
# Out:
# Finished 'prMetricsByThresh' in 6.9412 secs
# <style  type="text/css" >
#     #T_4ece5682_f044_11ec_9bae_64006ac0923arow0_col4 {
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow0_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow0_col6 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow1_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow1_col5 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow1_col6 {
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow2_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow2_col5 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow2_col6 {
#             background-color:  #58a1cf;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow3_col4 {
#             background-color:  #115ca5;
#             color:  #f1f1f1;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow3_col5 {
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow3_col6 {
#             background-color:  #08458a;
#             color:  #f1f1f1;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow4_col4 {
#             background-color:  #4090c5;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow4_col5 {
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow4_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow5_col4 {
#             background-color:  #7fb9da;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow5_col5 {
#             background-color:  #c6dbef;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow5_col6 {
#             background-color:  #08478d;
#             color:  #f1f1f1;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow6_col4 {
#             background-color:  #afd1e7;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow6_col5 {
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow6_col6 {
#             background-color:  #1b69af;
#             color:  #f1f1f1;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow7_col4 {
#             background-color:  #cbdef1;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow7_col5 {
#             background-color:  #a6cee4;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow7_col6 {
#             background-color:  #4191c6;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow8_col4 {
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow8_col5 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow8_col6 {
#             background-color:  #77b5d9;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow9_col4 {
#             background-color:  #e2edf8;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow9_col5 {
#             background-color:  #7fb9da;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow9_col6 {
#             background-color:  #a4cce3;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow10_col4 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow10_col5 {
#             background-color:  #6aaed6;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow10_col6 {
#             background-color:  #c1d9ed;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow11_col4 {
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow11_col5 {
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow11_col6 {
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow12_col4 {
#             background-color:  #eff6fc;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow12_col5 {
#             background-color:  #4a98c9;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow12_col6 {
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow13_col4 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow13_col5 {
#             background-color:  #3b8bc2;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow13_col6 {
#             background-color:  #e2edf8;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow14_col4 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow14_col5 {
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow14_col6 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow15_col4 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow15_col5 {
#             background-color:  #2070b4;
#             color:  #f1f1f1;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow15_col6 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow16_col4 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow16_col5 {
#             background-color:  #1764ab;
#             color:  #f1f1f1;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow16_col6 {
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow17_col4 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow17_col5 {
#             background-color:  #0d57a1;
#             color:  #f1f1f1;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow17_col6 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow18_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow18_col5 {
#             background-color:  #084a91;
#             color:  #f1f1f1;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow18_col6 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow19_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow19_col5 {
#             background-color:  #083c7d;
#             color:  #f1f1f1;
#         }    #T_4ece5682_f044_11ec_9bae_64006ac0923arow19_col6 {
#             background-color:  #f5fafe;

# %%
varThresh=0.025

# %% [markdown]
# # BOCD, Compute the run lengths and changepoints by using a multivariate Gaussian (with independent three dimensions of predictions) to model the prediction sequence

# %%
y_pred = results.t_out.coord_main
n_vec_dim=y_pred.shape[-1]
data_tensor = torch.tensor(y_pred).float()
batch_size_cpd = data_tensor.shape[0]
mu_prior = torch.zeros((batch_size_cpd, 1,n_vec_dim))
mean_var=torch.mean(torch.var(data_tensor, dim =1),dim=0).unsqueeze(0)
cov_prior = (mean_var.repeat(batch_size_cpd,1).unsqueeze(1)* torch.eye(n_vec_dim)).reshape(batch_size_cpd,1,n_vec_dim,n_vec_dim)
cov_x = cov_prior
likelihood_model = Multivariate_Gaussian(mu_prior, cov_prior, cov_x)
T = params.n_win
model_cpd = BOCD.BOCD(None, T, likelihood_model, batch_size_cpd)
posterior, _, predictive, e_mean = model_cpd.run_recursive(data_tensor, 'cpu')
# Out:
# Finished 'run_recursive' in 222.5258 secs

# %%
df_bocd=prMetricsByThresh(cpMethod.BOCD.name, model_cpd.cp, \
                        torch.tensor(valid_dataset.data['cps']).unsqueeze(2).float(), 20,1,10)
df_bocd.style.background_gradient(cmap="Blues")
# Out:
# Finished 'prMetricsByThresh' in 22.1515 secs
# <style  type="text/css" >
#     #T_e17f7452_f044_11ec_9bae_64006ac0923arow0_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow0_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow0_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow1_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow1_col5 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow1_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow2_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow2_col5 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow2_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow3_col4 {
#             background-color:  #2a7ab9;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow3_col5 {
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow3_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow4_col4 {
#             background-color:  #2a7ab9;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow4_col5 {
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow4_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow5_col4 {
#             background-color:  #084f99;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow5_col5 {
#             background-color:  #c6dbef;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow5_col6 {
#             background-color:  #08488e;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow6_col4 {
#             background-color:  #084f99;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow6_col5 {
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow6_col6 {
#             background-color:  #08488e;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow7_col4 {
#             background-color:  #083e81;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow7_col5 {
#             background-color:  #a6cee4;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow7_col6 {
#             background-color:  #2171b5;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow8_col4 {
#             background-color:  #083e81;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow8_col5 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow8_col6 {
#             background-color:  #2171b5;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow9_col4 {
#             background-color:  #083877;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow9_col5 {
#             background-color:  #7fb9da;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow9_col6 {
#             background-color:  #4292c6;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow10_col4 {
#             background-color:  #083877;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow10_col5 {
#             background-color:  #6aaed6;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow10_col6 {
#             background-color:  #4292c6;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow11_col4 {
#             background-color:  #083877;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow11_col5 {
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow11_col6 {
#             background-color:  #4292c6;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow12_col4 {
#             background-color:  #083573;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow12_col5 {
#             background-color:  #4a98c9;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow12_col6 {
#             background-color:  #65aad4;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow13_col4 {
#             background-color:  #083573;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow13_col5 {
#             background-color:  #3b8bc2;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow13_col6 {
#             background-color:  #65aad4;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow14_col4 {
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow14_col5 {
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow14_col6 {
#             background-color:  #82bbdb;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow15_col4 {
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow15_col5 {
#             background-color:  #2171b5;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow15_col6 {
#             background-color:  #82bbdb;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow16_col4 {
#             background-color:  #08316d;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow16_col5 {
#             background-color:  #1764ab;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow16_col6 {
#             background-color:  #9dcae1;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow17_col4 {
#             background-color:  #08316d;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow17_col5 {
#             background-color:  #0d57a1;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow17_col6 {
#             background-color:  #9dcae1;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow18_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow18_col5 {
#             background-color:  #084a91;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow18_col6 {
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow19_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow19_col5 {
#             background-color:  #083c7d;
#             color:  #f1f1f1;
#         }    #T_e17f7452_f044_11ec_9bae_64006ac0923arow19_col6 {
#             background-color:  #b2d2e8;

# %%
bocdThresh=4.0

# %% [markdown]
# # Summary Table with chosen thresholds

# %%
pd.options.display.float_format='{:,.4f}'.format
df_summary=pd.DataFrame(columns=list(t_prMetrics._fields)+['thresh'])
cpThresh=[nnThresh, gradThresh, bocdThresh, varThresh]
cp_target=valid_dataset.data['cps']
cp_pred_raw=[torch.tensor(results.t_out.cp_logits).float(), torch.tensor(results.t_out.coord_main).float(), 
             model_cpd.cp,  torch.tensor(results.t_out.y_var).float()]
for name, thresh, pred_raw in zip(['neural_network', 'gradient', 'BOCD', 'mc_dropout'], cpThresh, cp_pred_raw):
    prMetrics, _= reportChangePointMetrics(name, pred_raw, cp_target, thresh, win_tol=2)
    prMetrics['thresh']=thresh
    prMetrics['F1']=2*prMetrics['Precision']*prMetrics['Recall']/(prMetrics['Precision']+prMetrics['Recall'])
    prMetrics['Name']=name
    df_summary=df_summary.append(prMetrics, ignore_index=True)
df_summary
# Out:
#              Precision              Recall            Accuracy  \
# 0  0.32125390371810736  0.6902139511330548   0.987929648675511
# 1  0.14642857142857144  0.7578174452462337  0.9681889287411953
# 2   0.3920291929021179  0.6936321053297886   0.990564798409749
# 3  0.03379562080647034   0.847449044182808    0.83355602610086
#
#               A_major  BalancedAccuracy  thresh     F1            Name
# 0  0.9899760779914911            0.8401  0.6500 0.4384  neural_network
# 1  0.9696349739938441            0.8637  0.1500 0.2454        gradient
# 2  0.9926058455329195            0.8431  4.0000 0.5009            BOCD
# 3  0.8334605286859603            0.8405  0.0250 0.0650      mc_dropout

# %% [markdown]
# plot of Precision/Recall

# %%
fig, ax = plt.subplots(2,2,figsize=[12,12])

for (row,col), df, name in zip(itertools.product([0,1],[0,1]),[df_nn, df_grad, df_var, df_bocd],[cp.name for cp in cpMethod]) :
    ax[row,col].plot(df['Precision'], df['Recall'])
    ax[row,col].set_xlabel('Precision')
    ax[row,col].set_ylabel('Recall')
    ax[row,col].set_title(name)
    df_row=df_summary[df_summary.Name==name]
    ax[row,col].scatter(df_row['Precision'], df_row['Recall'], color='r')
plt.show()

# %%
fig, ax = plt.subplots(figsize=[10,8])

for df, name in zip([df_nn, df_grad, df_var, df_bocd],[cp.name for cp in cpMethod]) :
    aucScore = "N/A"
#     if name!="BOCD":
    aucScore = format(auc(df['Recall'], df['Precision'])*100, ".2f")
    plt.plot(df['Recall'], df['Precision'], label=str(name) + " AUC="+ str(aucScore)+"%")
    plt.ylabel('Precision', fontsize=15)
    plt.xlabel('Recall', fontsize=15)
    plt.title(f"Comparison of different methods for changepoint detection {params.model}")
    df_row=df_summary[df_summary.Name==name]
    plt.scatter(df_row['Recall'], df_row['Precision'], color='r')
    plt.legend(loc="best")
plt.show()

# %% [markdown]
# # Qualitative by looking at anecdotes/samples

# %%
granular_pop_dict = load_path(osp.join(labels_path, 'granular_pop.pkl'), en_pickle=True)
cp_target=valid_dataset.data['cps']
seqlen=cp_target.shape[1]
rev_pop_dict={v:k for k,v in granular_pop_dict.items()}
cp_pred_raw=[torch.tensor(results.t_out.cp_logits).float(), torch.tensor(results.t_out.coord_main).float(), 
             model_cpd.cp]
pred_cps = {}
for name, thresh, pred_raw in zip(['neural_network', 'gradient', 'BOCD'], cpThresh, cp_pred_raw):
    _, pred_cps[name]= reportChangePointMetrics(name, pred_raw, cp_target, thresh)

true_cps=cp_target
pred_cps={k:v.detach().cpu().numpy() for k,v in pred_cps.items()}

# %%
def plot_changepoints(true_cps, pred_cps, y_pred, bocp_rl, popNames):
    fig, ax = plt.subplots(7,1,figsize=[18,30])
    ax[0].plot(y_pred)
    ax[0].text(0, np.max(y_pred)-0.5, s=popNames[0], size=10)
    for i in np.nonzero(true_cps)[0]:
        ax[0].text(i, np.max(y_pred)-0.5, s=popNames[i+1], size=10, zorder=5)
    ax[1].plot(pred_cps[cpMethod.gradient.name])
#     ax[2].plot(y_var)
#     ax[3].plot(pred_cps[cpMethod.mc_dropout.name])
    ax[4].plot(pred_cps[cpMethod.neural_network.name])
    ax[5].plot(np.arange(T+1), bocp_rl)
    ax[6].plot(pred_cps[cpMethod.BOCD.name])
    for i in np.nonzero(true_cps)[0]:
        for j in [0,1,2,3,4,5,6]:
            ax[j].plot([i,i], [np.min(y_pred), np.max(y_pred)], 'r' , zorder=5)
            
            
    ax[0].set_title("n_vectors")
    ax[1].set_title("Simple gradient(post_process)")
    ax[2].set_title("Mc dropout variance")
    ax[3].set_title("Mc dropout")
    ax[4].set_title("Neural Network predicted cp")
    ax[5].set_title("BOCD (post process) run_length")
    ax[6].set_title("BOCD (post process) cp")
    plt.show()

# %%
index = 2270
true_cpsSample=true_cps[index,:]
pred_cpsSample={k:v[index,:] for k,v in pred_cps.items()}
y_predSample=results.t_out.coord_main[index,:]
# y_varSample=results.t_out.y_var[index,:,:]
bocp_rlSample=model_cpd.cp.detach().cpu().numpy()[index,:]
granularpopSample=valid_dataset.data['granular_pop'][index,:]
namesSample=[rev_pop_dict[i] for i in granularpopSample.astype(int)]
plot_changepoints(true_cpsSample, pred_cpsSample, y_predSample, bocp_rlSample, namesSample)

# %%
index = 2285
true_cpsSample=true_cps[index,:]
pred_cpsSample={k:v[index,:] for k,v in pred_cps.items()}
y_predSample=results.t_out.coord_main[index,:]
# y_varSample=results.t_out.y_var[index,:,:]
bocp_rlSample=model_cpd.cp.detach().cpu().numpy()[index,:]
granularpopSample=valid_dataset.data['granular_pop'][index,:]
namesSample=[rev_pop_dict[i] for i in granularpopSample.astype(int)]
plot_changepoints(true_cpsSample, pred_cpsSample, y_predSample, bocp_rlSample, namesSample)

# %%
index = 3600
true_cpsSample=true_cps[index,:]
pred_cpsSample={k:v[index,:] for k,v in pred_cps.items()}
y_predSample=results.t_out.coord_main[index,:]
# y_varSample=results.t_out.y_var[index,:,:]
bocp_rlSample=model_cpd.cp.detach().cpu().numpy()[index,:]
granularpopSample=valid_dataset.data['granular_pop'][index,:]
namesSample=[rev_pop_dict[i] for i in granularpopSample.astype(int)]
plot_changepoints(true_cpsSample, pred_cpsSample, y_predSample, bocp_rlSample, namesSample)

# %% [markdown]
# # evaluate on a subset of samples that have at least 1 changepoint

# %%
subset_idx=np.unique(np.nonzero(valid_dataset.data['cps'])[0])

# %%
df_summary_subset=pd.DataFrame(columns=list(t_prMetrics._fields)+['thresh'])
subsetSamples_trueCps=valid_dataset.data['cps'][..., np.newaxis][subset_idx,:]
cp_pred_raw=[torch.tensor(results.t_out.cp_logits[subset_idx,:]).float(), \
             torch.tensor(results.t_out.coord_main[subset_idx,:]).float(), 
             torch.tensor(results.t_out.y_var[subset_idx,:]).float(),\
             model_cpd.cp[subset_idx,:]]
for name, thresh, pred_raw in zip([cp.name for cp in cpMethod], cpThresh, cp_pred_raw):
    prMetrics, _= reportChangePointMetrics(name, pred_raw, subsetSamples_trueCps, thresh, win_tol=2)
    prMetrics['thresh']=thresh
    prMetrics['F1']=2*prMetrics['Precision']*prMetrics['Recall']/(prMetrics['Precision']+prMetrics['Recall'])
    prMetrics['Name']=name
    df_summary_subset=df_summary_subset.append(prMetrics, ignore_index=True)
df_summary_subset
# Out:
# /share/software/user/open/py-jupyter/1.0.0_py36/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning:
#
# invalid value encountered in double_scalars
#              Precision              Recall            Accuracy  \
# 0  0.34971135343168697  0.6902139511330548   0.981560466578071
# 1   0.1704927371119339  0.7578174452462337   0.954524608755152
# 2                  0.0                 0.0  0.9884263905840431
# 3                  0.0                 0.0  0.9884263905840431
#
#               A_major  BalancedAccuracy  thresh     F1            Name
# 0  0.9849718797157435            0.8376  0.6500 0.4642  neural_network
# 1  0.9568278777708931            0.8573  0.1500 0.2784        gradient
# 2                 1.0            0.5000  4.0000    nan      mc_dropout
# 3                 1.0            0.5000  0.0250    nan            BOCD

# %% [markdown]
# # compute metrics by placing win_tol=0

# %%
df_zero_tol=pd.DataFrame(columns=list(t_prMetrics._fields)+['thresh'])
trueCps=valid_dataset.data['cps'][..., np.newaxis]
cp_pred_raw=[torch.tensor(results.t_out.cp_logits).float(), \
             torch.tensor(results.t_out.coord_main).float(), 
             torch.tensor(results.t_out.y_var).float(),\
             model_cpd.cp]
for name, thresh, pred_raw in zip([cp.name for cp in cpMethod], cpThresh, cp_pred_raw):
    prMetrics, _= reportChangePointMetrics(name, pred_raw, trueCps, thresh, win_tol=0)
    prMetrics['thresh']=thresh
    prMetrics['F1']=2*prMetrics['Precision']*prMetrics['Recall']/(prMetrics['Precision']+prMetrics['Recall'])
    prMetrics['Name']=name
    df_zero_tol=df_zero_tol.append(prMetrics, ignore_index=True)
df_zero_tol
# Out:
# /share/software/user/open/py-jupyter/1.0.0_py36/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning:
#
# invalid value encountered in double_scalars
#              Precision               Recall            Accuracy  \
# 0  0.15660725261216965  0.48385871629320165  0.9786871786007519
# 1  0.09407246145949485   0.6728699835422205  0.9535300980942916
# 2                  0.0                  0.0  0.9931731558705328
# 3                  0.0                  0.0  0.9931731558705328
#
#               A_major  BalancedAccuracy  thresh     F1            Name
# 0  0.9820885157825212            0.7330  0.6500 0.2366  neural_network
# 1  0.9554592912506712            0.8142  0.1500 0.1651        gradient
# 2                 1.0            0.5000  4.0000    nan      mc_dropout
# 3                 1.0            0.5000  0.0250    nan            BOCD

# %% [markdown]
# # evaluate to make sure matches with scikit learn (subset with samples that have cp, and win_tol=0 for evaluation

# %%
df_summary_subset=pd.DataFrame(columns=list(t_prMetrics._fields)+['thresh'])
subsetSamples_trueCps=valid_dataset.data['cps'][..., np.newaxis][subset_idx,:]
cp_pred_raw=[torch.tensor(results.t_out.cp_logits[subset_idx,:]).float(), \
             torch.tensor(results.t_out.coord_main[subset_idx,:]).float(), 
             torch.tensor(results.t_out.y_var[subset_idx,:]).float(),\
             model_cpd.cp[subset_idx,:]]
for name, thresh, pred_raw in zip([cp.name for cp in cpMethod], cpThresh, cp_pred_raw):
    prMetrics, _= reportChangePointMetrics(name, pred_raw, subsetSamples_trueCps, thresh, win_tol=0)
    prMetrics['thresh']=thresh
    prMetrics['F1']=2*prMetrics['Precision']*prMetrics['Recall']/(prMetrics['Precision']+prMetrics['Recall'])
    prMetrics['Name']=name
    df_summary_subset=df_summary_subset.append(prMetrics, ignore_index=True)
df_summary_subset
# Out:
# /share/software/user/open/py-jupyter/1.0.0_py36/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning:
#
# invalid value encountered in double_scalars
#              Precision               Recall            Accuracy  \
# 0  0.16600069492703265  0.48385871629320165   0.965891625067216
# 1  0.10477241814346823   0.6728699835422205  0.9296733631159515
# 2                  0.0                  0.0  0.9884263905840431
# 3                  0.0                  0.0  0.9884263905840431
#
#               A_major  BalancedAccuracy  thresh     F1            Name
# 0  0.9715358092623503            0.7277  0.6500 0.2472  neural_network
# 1  0.9326803063139452            0.8028  0.1500 0.1813        gradient
# 2                 1.0            0.5000  4.0000    nan      mc_dropout
# 3                 1.0            0.5000  0.0250    nan            BOCD

# %% [markdown]
# # evaluate by Windows

# %%
df_nn=prMetricsByThresh(cpMethod.neural_network.name, torch.tensor(results.t_out.cp_logits).float(), \
                        valid_dataset.data['cps'][..., np.newaxis], 20, 0.4, 0.5, byWindows=True)
df_nn.style.background_gradient(cmap="Blues")
# Out:
# Finished 'prMetricsByThresh' in 83.5419 secs
# <style  type="text/css" >
#     #T_1b1b599c_f045_11ec_9bae_64006ac0923arow0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow0_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow0_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow0_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow0_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow1_col0 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow1_col1 {
#             background-color:  #084082;
#             color:  #f1f1f1;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow1_col2 {
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow1_col3 {
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow1_col4 {
#             background-color:  #084082;
#             color:  #f1f1f1;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow1_col5 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow1_col6 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow2_col0 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow2_col1 {
#             background-color:  #084d96;
#             color:  #f1f1f1;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow2_col2 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow2_col3 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow2_col4 {
#             background-color:  #084d96;
#             color:  #f1f1f1;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow2_col5 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow2_col6 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow3_col0 {
#             background-color:  #dae8f6;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow3_col1 {
#             background-color:  #0e58a2;
#             color:  #f1f1f1;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow3_col2 {
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow3_col3 {
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow3_col4 {
#             background-color:  #0d57a1;
#             color:  #f1f1f1;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow3_col5 {
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow3_col6 {
#             background-color:  #dae8f6;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow4_col0 {
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow4_col1 {
#             background-color:  #1460a8;
#             color:  #f1f1f1;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow4_col2 {
#             background-color:  #cee0f2;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow4_col3 {
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow4_col4 {
#             background-color:  #135fa7;
#             color:  #f1f1f1;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow4_col5 {
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow4_col6 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow5_col0 {
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow5_col1 {
#             background-color:  #2272b6;
#             color:  #f1f1f1;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow5_col2 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow5_col3 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow5_col4 {
#             background-color:  #2171b5;
#             color:  #f1f1f1;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow5_col5 {
#             background-color:  #c6dbef;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow5_col6 {
#             background-color:  #c7dcef;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow6_col0 {
#             background-color:  #bfd8ed;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow6_col1 {
#             background-color:  #3686c0;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow6_col2 {
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow6_col3 {
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow6_col4 {
#             background-color:  #3888c1;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow6_col5 {
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow6_col6 {
#             background-color:  #bfd8ed;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow7_col0 {
#             background-color:  #b4d3e9;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow7_col1 {
#             background-color:  #4d99ca;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow7_col2 {
#             background-color:  #a8cee4;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow7_col3 {
#             background-color:  #a8cee4;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow7_col4 {
#             background-color:  #529dcc;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow7_col5 {
#             background-color:  #a6cee4;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow7_col6 {
#             background-color:  #b4d3e9;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow8_col0 {
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow8_col1 {
#             background-color:  #529dcc;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow8_col2 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_1b1b599c_f045_11ec_9bae_64006ac0923arow8_col3 {
#             background-color:  #92c4de;
#             color:  #000000;

# %%
df_grad=prMetricsByThresh(cpMethod.gradient.name, torch.tensor(results.t_out.coord_main).float(), \
                        valid_dataset.data['cps'][..., np.newaxis], 20, 0,1, byWindows=True)
df_grad.style.background_gradient(cmap="Blues")
# Out:
# Finished 'prMetricsByThresh' in 91.6387 secs
# <style  type="text/css" >
#     #T_528a8916_f045_11ec_9bae_64006ac0923arow0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow0_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow0_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow0_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow0_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow0_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow1_col0 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow1_col1 {
#             background-color:  #1865ac;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow1_col2 {
#             background-color:  #1d6cb1;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow1_col3 {
#             background-color:  #1e6db2;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow1_col4 {
#             background-color:  #084b93;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow1_col5 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow1_col6 {
#             background-color:  #e3eef8;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow2_col0 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow2_col1 {
#             background-color:  #3080bd;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow2_col2 {
#             background-color:  #084488;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow2_col3 {
#             background-color:  #08458a;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow2_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow2_col5 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow2_col6 {
#             background-color:  #b4d3e9;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow3_col0 {
#             background-color:  #dceaf6;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow3_col1 {
#             background-color:  #4090c5;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow3_col2 {
#             background-color:  #083a7a;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow3_col3 {
#             background-color:  #083b7c;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow3_col4 {
#             background-color:  #083877;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow3_col5 {
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow3_col6 {
#             background-color:  #71b1d7;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow4_col0 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow4_col1 {
#             background-color:  #529dcc;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow4_col2 {
#             background-color:  #083776;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow4_col3 {
#             background-color:  #083776;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow4_col4 {
#             background-color:  #08468b;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow4_col5 {
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow4_col6 {
#             background-color:  #4896c8;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow5_col0 {
#             background-color:  #cde0f1;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow5_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow5_col2 {
#             background-color:  #083573;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow5_col3 {
#             background-color:  #083573;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow5_col4 {
#             background-color:  #0b559f;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow5_col5 {
#             background-color:  #c6dbef;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow5_col6 {
#             background-color:  #2d7dbb;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow6_col0 {
#             background-color:  #c7dbef;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow6_col1 {
#             background-color:  #75b4d8;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow6_col2 {
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow6_col3 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow6_col4 {
#             background-color:  #1865ac;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow6_col5 {
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow6_col6 {
#             background-color:  #1b69af;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow7_col0 {
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow7_col1 {
#             background-color:  #89bedc;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow7_col2 {
#             background-color:  #08326e;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow7_col3 {
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow7_col4 {
#             background-color:  #2474b7;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow7_col5 {
#             background-color:  #a6cee4;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow7_col6 {
#             background-color:  #0d57a1;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow8_col0 {
#             background-color:  #abd0e6;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow8_col1 {
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow8_col2 {
#             background-color:  #08326e;
#             color:  #f1f1f1;
#         }    #T_528a8916_f045_11ec_9bae_64006ac0923arow8_col3 {
#             background-color:  #08326e;
#             color:  #f1f1f1;

# %%
df_var=prMetricsByThresh(cpMethod.mc_dropout.name, torch.tensor(results.t_out.y_var).float(), \
                        valid_dataset.data['cps'][..., np.newaxis], 20, 0,0.5, byWindows=True)
df_var.style.background_gradient(cmap="Blues")
# Out:
# Finished 'prMetricsByThresh' in 90.2532 secs
# <style  type="text/css" >
#     #T_8931292a_f045_11ec_9bae_64006ac0923arow0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow0_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow0_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow0_col4 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow0_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow0_col6 {
#             background-color:  #e2edf8;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow1_col0 {
#             background-color:  #cadef0;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow1_col1 {
#             background-color:  #4b98ca;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow1_col2 {
#             background-color:  #125ea6;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow1_col3 {
#             background-color:  #135fa7;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow1_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow1_col5 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow1_col6 {
#             background-color:  #97c6df;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow2_col0 {
#             background-color:  #56a0ce;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow2_col1 {
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow2_col2 {
#             background-color:  #083d7f;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow2_col3 {
#             background-color:  #083d7f;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow2_col4 {
#             background-color:  #1f6eb3;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow2_col5 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow2_col6 {
#             background-color:  #206fb4;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow3_col0 {
#             background-color:  #084c95;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow3_col1 {
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow3_col2 {
#             background-color:  #083573;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow3_col3 {
#             background-color:  #083573;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow3_col4 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow3_col5 {
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow3_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow4_col0 {
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow4_col1 {
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow4_col2 {
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow4_col3 {
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow4_col4 {
#             background-color:  #a9cfe5;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow4_col5 {
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow4_col6 {
#             background-color:  #083c7d;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow5_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow5_col1 {
#             background-color:  #e3eef8;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow5_col2 {
#             background-color:  #08326e;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow5_col3 {
#             background-color:  #08326e;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow5_col4 {
#             background-color:  #cadef0;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow5_col5 {
#             background-color:  #c6dbef;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow5_col6 {
#             background-color:  #125da6;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow6_col0 {
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow6_col1 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow6_col2 {
#             background-color:  #08316d;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow6_col3 {
#             background-color:  #08316d;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow6_col4 {
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow6_col5 {
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow6_col6 {
#             background-color:  #3383be;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow7_col0 {
#             background-color:  #084285;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow7_col1 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow7_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow7_col3 {
#             background-color:  #08316d;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow7_col4 {
#             background-color:  #e3eef8;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow7_col5 {
#             background-color:  #a6cee4;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow7_col6 {
#             background-color:  #5fa6d1;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow8_col0 {
#             background-color:  #1764ab;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow8_col1 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow8_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8931292a_f045_11ec_9bae_64006ac0923arow8_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;

# %%
df_bocd=prMetricsByThresh(cpMethod.BOCD.name, model_cpd.cp, \
                        valid_dataset.data['cps'][..., np.newaxis], 20,1,11, byWindows=True)
df_bocd.style.background_gradient(cmap="Blues")
# Out:
# Finished 'prMetricsByThresh' in 105.7467 secs
# <style  type="text/css" >
#     #T_c915fbf6_f045_11ec_9bae_64006ac0923arow0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow0_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow0_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow0_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow1_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow1_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow1_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow1_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow1_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow1_col5 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow1_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow2_col0 {
#             background-color:  #105ba4;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow2_col1 {
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow2_col2 {
#             background-color:  #519ccc;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow2_col3 {
#             background-color:  #58a1cf;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow2_col4 {
#             background-color:  #1d6cb1;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow2_col5 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow2_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow3_col0 {
#             background-color:  #105ba4;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow3_col1 {
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow3_col2 {
#             background-color:  #519ccc;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow3_col3 {
#             background-color:  #58a1cf;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow3_col4 {
#             background-color:  #1d6cb1;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow3_col5 {
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow3_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow4_col0 {
#             background-color:  #61a7d2;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow4_col1 {
#             background-color:  #0a549e;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow4_col2 {
#             background-color:  #9ac8e0;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow4_col3 {
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow4_col4 {
#             background-color:  #084e98;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow4_col5 {
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow4_col6 {
#             background-color:  #135fa7;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow5_col0 {
#             background-color:  #61a7d2;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow5_col1 {
#             background-color:  #0a549e;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow5_col2 {
#             background-color:  #9ac8e0;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow5_col3 {
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow5_col4 {
#             background-color:  #084e98;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow5_col5 {
#             background-color:  #c6dbef;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow5_col6 {
#             background-color:  #135fa7;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow6_col0 {
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow6_col1 {
#             background-color:  #084387;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow6_col2 {
#             background-color:  #bed8ec;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow6_col3 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow6_col4 {
#             background-color:  #083d7f;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow6_col5 {
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow6_col6 {
#             background-color:  #2a7ab9;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow7_col0 {
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow7_col1 {
#             background-color:  #084387;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow7_col2 {
#             background-color:  #bed8ec;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow7_col3 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow7_col4 {
#             background-color:  #083d7f;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow7_col5 {
#             background-color:  #a6cee4;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow7_col6 {
#             background-color:  #2a7ab9;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow8_col0 {
#             background-color:  #bcd7eb;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow8_col1 {
#             background-color:  #083b7c;
#             color:  #f1f1f1;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow8_col2 {
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }    #T_c915fbf6_f045_11ec_9bae_64006ac0923arow8_col3 {
#             background-color:  #d2e3f3;
#             color:  #000000;

# %%
fig, ax = plt.subplots(2,2,figsize=[12,12])

for (row,col), df, name in zip(itertools.product([0,1],[0,1]),[df_nn, df_grad, df_var, df_bocd],[cp.name for cp in cpMethod]) :
    ax[row,col].plot(df['Precision'], df['Recall'])
    ax[row,col].set_xlabel('Precision')
    ax[row,col].set_ylabel('Recall')
    ax[row,col].set_title(name)
plt.show()

# %% [markdown]
# # load the model and evaluate with test data on the chosen hyperparameters

# %%
# Specify the dataset to be evaluated
# chm22 pca full dataset and model
labels_path = osp.join(os.environ['OUT_PATH'],'humans/labels/data_id_4_geo')
data_path = osp.join(os.environ['OUT_PATH'],'humans/labels/data_id_4_geo')
models_path=osp.join(os.environ['OUT_PATH'],'humans/training/Model_Q_exp_id_3_data_id_4_geo/') 
dataset_type='test'

# %%
config={}
config['data.labels']=labels_path 
config['data.dir']=data_path 
config['models.dir']=models_path
config['data.dataset_type']=dataset_type
config['cuda']='cuda'
config['model.loadBest']=False
json_path = osp.join(config['models.dir'], 'params.yaml')
assert osp.isfile(json_path), "No json configuration file found at {}".format(json_path)
params = Params(json_path)
params.rtnOuts=True
params.mc_dropout=True
params.mc_samples=100
params.cp_tol=0
results, test_dataset,_,_=inference.main(config, params)
results.t_out.coord_main=results.t_out.coord_main.mean(0)
# Out:
# INFO: __init__:src.main.dataset: Loading test Dataset
# INFO: __init__:src.main.dataset:Loading gen 0
# INFO: __init__:src.main.dataset: snps data: (540, 317410)
#  device used: cuda
# Loading the datasets...
# INFO: __init__:src.main.dataset: y_labels data :(540, 317410)
# INFO: __init__:src.main.dataset:Loading gen 2
# INFO: __init__:src.main.dataset: snps data: (800, 317410)
# INFO: __init__:src.main.dataset: y_labels data :(800, 317410)
# INFO: __init__:src.main.dataset:Loading gen 4
# INFO: __init__:src.main.dataset: snps data: (800, 317410)
# INFO: __init__:src.main.dataset: y_labels data :(800, 317410)
# INFO: __init__:src.main.dataset:Loading gen 8
# INFO: __init__:src.main.dataset: snps data: (800, 317410)
# INFO: __init__:src.main.dataset: y_labels data :(800, 317410)
# INFO: transform_data:src.main.dataset:Transforming the data
# Finished '_geoConvertLatLong2nVec' in 0.0665 secs
# Finished 'mapping_func' in 0.2759 secs
# Finished 'pop_mapping' in 0.1103 secs
# Finished 'pop_mapping' in 0.1089 secs
# Finished 'transform_data' in 33.7295 secs
# Finished '__init__' in 40.4368 secs
# Parameter count for model AuxNetwork:31747503
# Parameter count for model TransformerModel:107528
# Parameter count for model BiRNN:34499
# Parameter count for model logits_Block:2289
# Total parameters:31891819
# device in load model:None
# Finished 'load_model' in 0.1856 secs
# best val loss metrics : {'loss_main': 870.9366320208127, 'loss_aux': 2159.4718245838935, 'l1_loss': 0.20176482126010942, 'mse': 0.04551312713889611, 'smooth_l1': 0.022700810348433586, 'weighted_loss': 0.20176482126010942}
# at epoch : 299
# train loss metrics: {'loss_main': 250.43061244635055, 'loss_aux': 1543.2047426592148, 'l1_loss': 0.05562154084609267, 'mse': 0.004964988799775602, 'smooth_l1': 0.0024777479588382533, 'weighted_loss': 0.05562154084609267}
# best val cp metrics : {'loss_cp': 0.5664151318948706, 'prMetrics': OrderedDict([('Precision', array(0.03853326)), ('Recall', array(0.8925266)), ('Accuracy', array(0.62775502)), ('A_major', array(0.62327608)), ('BalancedAccuracy', 0.7579013402191457)])}
# train cp metrics: {'loss_cp': 0.27823506920098634, 'prMetrics': OrderedDict([('Precision', array(0.43575769)), ('Recall', array(0.80989654)), ('Accuracy', array(0.98191438)), ('A_major', array(0.98446293)), ('BalancedAccuracy', 0.897179733179963)])}
# best val sp metrics : None
# train sp metrics: None
# best val balanced gcd metrics : {'meanBalancedGcdSp': 852.7428232916327, 'meanBalancedGcdGp': 988.4041417065357, 'medianBalancedGcdSp': 860.4525610587058, 'medianBalancedGcdGp': 897.2618518239373, 'median': 504.17877197265625}
# train balanced gcd metrics: {'meanBalancedGcdSp': 339.3054164135748, 'meanBalancedGcdGp': 458.2800328256185, 'medianBalancedGcdSp': 243.11493158110028, 'medianBalancedGcdGp': 398.42678984153235, 'median': 116.06553649902344}
# is the model on cuda? : True
# Finished 'batchLoopValid' in 119.5360 secs
# Finished 'main' in 160.4531 secs

# %% [markdown]
# # Summary Table with test data

# %% [markdown]
# compute BOCD

# %%
y_pred = results.t_out.coord_main
n_vec_dim=y_pred.shape[-1]
test_tensor = torch.tensor(y_pred).float()
batch_size_cpd = test_tensor.shape[0]
mu_prior = torch.zeros((batch_size_cpd, 1,n_vec_dim))
cov_prior = (mean_var.repeat(batch_size_cpd,1).unsqueeze(1)* torch.eye(n_vec_dim)).reshape(batch_size_cpd,1,n_vec_dim,n_vec_dim)
cov_x = cov_prior
likelihood_model = Multivariate_Gaussian(mu_prior, cov_prior, cov_x)
T = params.n_win
model_cpd = BOCD.BOCD(None, T, likelihood_model, batch_size_cpd)
posterior, _, predictive, e_mean = model_cpd.run_recursive(test_tensor, 'cpu')
# Out:
# Finished 'run_recursive' in 172.3575 secs

# %%
df_test=pd.DataFrame(columns=list(t_prMetrics._fields)+['thresh'])
trueCps=test_dataset.data['cps']
cp_pred_raw=[torch.tensor(results.t_out.cp_logits).float(), \
             torch.tensor(results.t_out.coord_main).float(), 
             torch.tensor(results.t_out.y_var).float(),\
             model_cpd.cp]
for name, thresh, pred_raw in zip([cp.name for cp in cpMethod], cpThresh, cp_pred_raw):
    prMetrics, _= reportChangePointMetrics(name, pred_raw, trueCps, thresh, win_tol=2)
    prMetrics['thresh']=thresh
    prMetrics['F1']=2*prMetrics['Precision']*prMetrics['Recall']/(prMetrics['Precision']+prMetrics['Recall'])
    prMetrics['Name']=name
    df_test=df_test.append(prMetrics, ignore_index=True)
df_test
# Out:
# /share/software/user/open/py-jupyter/1.0.0_py36/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning:
#
# invalid value encountered in double_scalars
#               Precision              Recall            Accuracy  \
# 0  0.028968555430950973  0.9137821731963991  0.7400587995450546
# 1    0.6628304821150856  0.5403829085837454   0.993784201377712
# 2                   0.0                 0.0  0.9915373720466104
# 3                   0.0                 0.0  0.9915373720466104
#
#               A_major  BalancedAccuracy  thresh     F1            Name
# 0  0.7385760956959959            0.8262  0.6500 0.0562  neural_network
# 1  0.9976539157855324            0.7690  0.1500 0.5954        gradient
# 2                 1.0            0.5000  4.0000    nan      mc_dropout
# 3                 1.0            0.5000  0.0250    nan            BOCD
